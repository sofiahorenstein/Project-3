# %%
import pandas as pd
import numpy as np

# %%
top_50_2019=pd.read_csv('top50.csv',encoding = "ISO-8859-1")

# %%
top_50_2019
# Out:
#     Unnamed: 0                                         Track.Name  \
# 0            1                                           Señorita
# 1            2                                              China
# 2            3                      boyfriend (with Social House)
# 3            4                    Beautiful People (feat. Khalid)
# 4            5                        Goodbyes (Feat. Young Thug)
# 5            6                  I Don't Care (with Justin Bieber)
# 6            7                                             Ransom
# 7            8                                  How Do You Sleep?
# 8            9                              Old Town Road - Remix
# 9           10                                            bad guy
# 10          11                                           Callaita
# 11          12              Loco Contigo (feat. J. Balvin & Tyga)
# 12          13                                  Someone You Loved
# ...

# %%
top_50_2019.drop(top_50_2019.columns[top_50_2019.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)
top_50_2019
# Out:
#                                                  name           artists  \
# 0                                            Señorita      Shawn Mendes
# 1                                               China          Anuel AA
# 2                       boyfriend (with Social House)     Ariana Grande
# 3                     Beautiful People (feat. Khalid)        Ed Sheeran
# 4                         Goodbyes (Feat. Young Thug)       Post Malone
# 5                   I Don't Care (with Justin Bieber)        Ed Sheeran
# 6                                              Ransom         Lil Tecca
# 7                                   How Do You Sleep?         Sam Smith
# 8                               Old Town Road - Remix         Lil Nas X
# 9                                             bad guy     Billie Eilish
# 10                                           Callaita         Bad Bunny
# 11              Loco Contigo (feat. J. Balvin & Tyga)          DJ Snake
# ...

# %%
top_100_2018=pd.read_csv('../Downloads/top2018.csv',encoding = "ISO-8859-1")
top_100_2018
# Out:
#                        id                                               name  \
# 0   6DCZcSspjsKoFjzjrWoCd                                         God's Plan
# 1   3ee8Jmje8o58CHK66QrVC                                               SAD!
# 2   0e7ipj03S05BNilyu5bRz                         rockstar (feat. 21 Savage)
# 3   3swc6WTsr7rl9DqQKQA55                       Psycho (feat. Ty Dolla $ign)
# 4   2G7V7zsVDxg1yRsu7Ew9R                                     In My Feelings
# 5   7dt6x5M1jzdTEt8oCbisT                                         Better Now
# 6   58q2HKrzhC3ozto2nDdN4                                          I Like It
# 7   7ef4DlsgrMEH11cDZd32M                           One Kiss (with Dua Lipa)
# 8   76cy1WJvNGJTj78UqeA5z                                              IDGAF
# 9   08bNPGLD8AhKpnnERrAc6                                            FRIENDS
# 10  1rfofaqEpACxVEHIZBJe6                                             Havana
# ...

# %%
top_100_2017=pd.read_csv('../Downloads/featuresdf 2.csv',encoding = "ISO-8859-1")
top_100_2017
# Out:
#                        id                                               name  \
# 0   7qiZfU4dY1lWllzX7mPBI                                       Shape of You
# 1   5CtI0qwDJkDQGwXD1H1cL                                  Despacito - Remix
# 2   4aWmUDTfIPGksMNLV2rQP                 Despacito (Featuring Daddy Yankee)
# 3   6RUKPb4LETWmmr3iAEQkt                           Something Just Like This
# 4   3DXncPQOG4VBw3QHh3S81                                        I'm the One
# 5   7KXjTSCq5nL1LoYtL7XAw                                            HUMBLE.
# 6   3eR23VReFzcdmS7TYCrhC                    It Ain't Me (with Selena Gomez)
# 7   3B54sVLJ402zGa6Xm4YGN                                      Unforgettable
# 8   0KKkJNfGyhkQ5aFogxQAP                                 That's What I Like
# 9   3NdDpSvN911VPGivFlV5d  I Donât Wanna Live Forever (Fifty Shades Dar...
# 10  7GX5flRQZVHRAGd6B4TmD                                      XO TOUR Llif3
# ...

# %%
top_2017_2018=top_100_2017.append(top_100_2018)
top_2017_2018
# Out:
#                        id                                               name  \
# 0   7qiZfU4dY1lWllzX7mPBI                                       Shape of You
# 1   5CtI0qwDJkDQGwXD1H1cL                                  Despacito - Remix
# 2   4aWmUDTfIPGksMNLV2rQP                 Despacito (Featuring Daddy Yankee)
# 3   6RUKPb4LETWmmr3iAEQkt                           Something Just Like This
# 4   3DXncPQOG4VBw3QHh3S81                                        I'm the One
# 5   7KXjTSCq5nL1LoYtL7XAw                                            HUMBLE.
# 6   3eR23VReFzcdmS7TYCrhC                    It Ain't Me (with Selena Gomez)
# 7   3B54sVLJ402zGa6Xm4YGN                                      Unforgettable
# 8   0KKkJNfGyhkQ5aFogxQAP                                 That's What I Like
# 9   3NdDpSvN911VPGivFlV5d  I Donât Wanna Live Forever (Fifty Shades Dar...
# 10  7GX5flRQZVHRAGd6B4TmD                                      XO TOUR Llif3
# ...

# %%
top_2017_2018['Length.']=top_2017_2018['duration_ms']*.001
top_2017_2018
# Out:
#                        id                                               name  \
# 0   7qiZfU4dY1lWllzX7mPBI                                       Shape of You
# 1   5CtI0qwDJkDQGwXD1H1cL                                  Despacito - Remix
# 2   4aWmUDTfIPGksMNLV2rQP                 Despacito (Featuring Daddy Yankee)
# 3   6RUKPb4LETWmmr3iAEQkt                           Something Just Like This
# 4   3DXncPQOG4VBw3QHh3S81                                        I'm the One
# 5   7KXjTSCq5nL1LoYtL7XAw                                            HUMBLE.
# 6   3eR23VReFzcdmS7TYCrhC                    It Ain't Me (with Selena Gomez)
# 7   3B54sVLJ402zGa6Xm4YGN                                      Unforgettable
# 8   0KKkJNfGyhkQ5aFogxQAP                                 That's What I Like
# 9   3NdDpSvN911VPGivFlV5d  I Donât Wanna Live Forever (Fifty Shades Dar...
# 10  7GX5flRQZVHRAGd6B4TmD                                      XO TOUR Llif3
# ...

# %%
decimals = 0
top_2017_2018['Length.'] = top_2017_2018['Length.'].apply(lambda x: round(x, decimals))

# %%
top_2017_2018
# Out:
#                        id                                               name  \
# 0   7qiZfU4dY1lWllzX7mPBI                                       Shape of You
# 1   5CtI0qwDJkDQGwXD1H1cL                                  Despacito - Remix
# 2   4aWmUDTfIPGksMNLV2rQP                 Despacito (Featuring Daddy Yankee)
# 3   6RUKPb4LETWmmr3iAEQkt                           Something Just Like This
# 4   3DXncPQOG4VBw3QHh3S81                                        I'm the One
# 5   7KXjTSCq5nL1LoYtL7XAw                                            HUMBLE.
# 6   3eR23VReFzcdmS7TYCrhC                    It Ain't Me (with Selena Gomez)
# 7   3B54sVLJ402zGa6Xm4YGN                                      Unforgettable
# 8   0KKkJNfGyhkQ5aFogxQAP                                 That's What I Like
# 9   3NdDpSvN911VPGivFlV5d  I Donât Wanna Live Forever (Fifty Shades Dar...
# 10  7GX5flRQZVHRAGd6B4TmD                                      XO TOUR Llif3
# ...

# %%
top_2017_2018.keys()
# Out:
# Index(['id', 'name', 'artists', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'Length.'],
#       dtype='object')

# %%
top_50_2019.rename(columns={"Track.Name": 'name', "Artist.Name": 'artists', "Danceability": "danceability", "Loudness..dB..": "loudness", "Liveness": "liveness", "Valence.": "valence", "accousticness": "acousticness", "Speechiness.": "speechiness", "Beats.Per.Minute":"tempo", "Energy": "energy"}, inplace=True)
top_50_2019_2=top_50_2019.drop(columns=["Popularity"],axis=1)

# %%
top_2017_2018_2019=top_2017_2018.append(top_50_2019_2)
top_2017_2018_2019
top_2017_2018_2019_2=top_2017_2018_2019.drop(columns=["instrumentalness", "mode", "id", "key", "time_signature"])
top_2017_2018_2019_2
# Out:
#                Genre  Length.  acousticness           artists  danceability  \
# 0                NaN    234.0      0.581000        Ed Sheeran         0.825
# 1                NaN    229.0      0.229000        Luis Fonsi         0.694
# 2                NaN    228.0      0.209000        Luis Fonsi         0.660
# 3                NaN    247.0      0.049800  The Chainsmokers         0.617
# 4                NaN    289.0      0.055200         DJ Khaled         0.609
# 5                NaN    177.0      0.000259    Kendrick Lamar         0.904
# 6                NaN    221.0      0.119000              Kygo         0.640
# 7                NaN    234.0      0.029300    French Montana         0.726
# 8                NaN    207.0      0.013000        Bruno Mars         0.853
# 9                NaN    245.0      0.063100              ZAYN         0.735
# 10               NaN    183.0      0.002640      Lil Uzi Vert         0.732
# ...

# %%
top_2017_2018_2019_2.isna().sum()
# Out:
# Genre           200
# Length.           0
# acousticness      0
# artists           0
# danceability      0
# energy            0
# liveness          0
# loudness          0
# name              0
# speechiness       0
# tempo             0
# valence           0
# dtype: int64

# %%
top_2017_2018_2019_2.dtypes
# Out:
# Genre            object
# Length.         float64
# acousticness    float64
# artists          object
# danceability    float64
# energy          float64
# liveness        float64
# loudness        float64
# name             object
# speechiness     float64
# tempo           float64
# valence         float64
# dtype: object
