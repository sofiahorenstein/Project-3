# %% [markdown]
# # SpotiPY API Call

# %% [markdown]
# ## Dependencies

# %% [markdown]
# ### Libraries

# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.oauth2 as oauth2
import pandas as pd

from config import client_id, client_secret

# %% [markdown]
# ### Access Token (Auth. Code Flow)

# %%
# Get Access Token
# Authorization Code Flow Method
cid = client_id
secret = client_secret

credentials = oauth2.SpotifyClientCredentials(client_id=cid, client_secret=secret)

token = credentials.get_access_token()
sp = spotipy.Spotify(auth=token)

# %% [markdown]
# ## Data Retrieval

# %% [markdown]
# ### 1990

# %%
# Lists to store data
track_name = []
artist = []
track_id = []
popularity = []

# %%
# Loop through general track info
for i in range(0, 1000, 50):
    year_1990 = sp.search(q='year:1990', type='track', limit=50, offset=i)
    for i, a in enumerate(year_1990['tracks']['items']):
        
        track_name.append(a['name'])
        artist.append(a['artists'][0]['name'])
        popularity.append(a['popularity'])
        track_id.append(a['id'])

len(track_name)
# Out:
# 1000

# %%
df_1990 = pd.DataFrame({'track':track_name, 'artist':artist, 'popularity':popularity, 'id':track_id})
df_1990.head()
# Out:
#                         track                        artist  popularity  \
# 0          Carol of the Bells  Mykola Dmytrovych Leontovych          79
# 1              This Christmas                Donny Hathaway          78
# 2               Thunderstruck                         AC/DC          81
# 3  Don't Go Breaking My Heart                    Elton John          69
# 4              Man in the Box               Alice In Chains          71
#
#                        id
# 0  4tHqQMWSqmL6YjXwsqthDI
# 1  38xhBO2AKrJnjdjVnhJES6
# 2  57bgtoPSgt236HzfBOd8kj
# 3  5pKJtX4wBeby9qIfFhyOJj
# 4  6gZVQvQZOFpzIy3HblJ20F

# %%
# Get track feautured information

# Lists to match data to df_1990
new90 = []
limitsize = 100
none90 = 0

# %%
# Get track feautured information
for i in range(0, len(df_1990['id']), limitsize):
    feat_90 = df_1990['id'][i:i+limitsize]
    res_90 = sp.audio_features(feat_90)
    for i, a in enumerate(res_90):
        if a == None:
            none90 = none90 + 1
        else:
            new90.append(a)
            
len(new90)
# Out:
# 1000

# %%
info90 = pd.DataFrame.from_dict(new90, orient='columns')
info90.head()
# Out:
#    acousticness                                       analysis_url  \
# 0      0.994000  https://api.spotify.com/v1/audio-analysis/4tHq...
# 1      0.292000  https://api.spotify.com/v1/audio-analysis/38xh...
# 2      0.000147  https://api.spotify.com/v1/audio-analysis/57bg...
# 3      0.177000  https://api.spotify.com/v1/audio-analysis/5pKJ...
# 4      0.002290  https://api.spotify.com/v1/audio-analysis/6gZV...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.418        85267   0.106  4tHqQMWSqmL6YjXwsqthDI
# 1         0.634       231173   0.645  38xhBO2AKrJnjdjVnhJES6
# 2         0.501       292880   0.889  57bgtoPSgt236HzfBOd8kj
# 3         0.742       271133   0.863  5pKJtX4wBeby9qIfFhyOJj
# 4         0.346       284427   0.765  6gZVQvQZOFpzIy3HblJ20F
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.029200    8    0.1790   -22.507     0       0.0448   46.718
# 1          0.000000    5    0.2460    -9.200     1       0.0376   93.050
# 2          0.011400    4    0.2170    -5.175     1       0.0364  133.519
# 3          0.000006    5    0.0699    -7.823     1       0.0380  131.196
# 4          0.000008    8    0.2130    -8.558     1       0.0413  106.463
#
#    time_signature                                         track_href  \
# 0               4  https://api.spotify.com/v1/tracks/4tHqQMWSqmL6...
# 1               4  https://api.spotify.com/v1/tracks/38xhBO2AKrJn...
# 2               4  https://api.spotify.com/v1/tracks/57bgtoPSgt23...
# 3               4  https://api.spotify.com/v1/tracks/5pKJtX4wBeby...
# 4               4  https://api.spotify.com/v1/tracks/6gZVQvQZOFpz...
#
#              type                                   uri  valence
# 0  audio_features  spotify:track:4tHqQMWSqmL6YjXwsqthDI    0.800
# 1  audio_features  spotify:track:38xhBO2AKrJnjdjVnhJES6    0.677
# 2  audio_features  spotify:track:57bgtoPSgt236HzfBOd8kj    0.257
# 3  audio_features  spotify:track:5pKJtX4wBeby9qIfFhyOJj    0.776
# 4  audio_features  spotify:track:6gZVQvQZOFpzIy3HblJ20F    0.644

# %%
# Join both datasets
df90 = pd.merge(df_1990, info90, on='id', how='inner')
df90.head()
# Out:
#                         track                        artist  popularity  \
# 0          Carol of the Bells  Mykola Dmytrovych Leontovych          79
# 1              This Christmas                Donny Hathaway          78
# 2               Thunderstruck                         AC/DC          81
# 3  Don't Go Breaking My Heart                    Elton John          69
# 4              Man in the Box               Alice In Chains          71
#
#                        id  acousticness  \
# 0  4tHqQMWSqmL6YjXwsqthDI      0.994000
# 1  38xhBO2AKrJnjdjVnhJES6      0.292000
# 2  57bgtoPSgt236HzfBOd8kj      0.000147
# 3  5pKJtX4wBeby9qIfFhyOJj      0.177000
# 4  6gZVQvQZOFpzIy3HblJ20F      0.002290
#
#                                         analysis_url  danceability  \
# 0  https://api.spotify.com/v1/audio-analysis/4tHq...         0.418
# 1  https://api.spotify.com/v1/audio-analysis/38xh...         0.634
# 2  https://api.spotify.com/v1/audio-analysis/57bg...         0.501
# 3  https://api.spotify.com/v1/audio-analysis/5pKJ...         0.742
# 4  https://api.spotify.com/v1/audio-analysis/6gZV...         0.346
#
#    duration_ms  energy  instrumentalness  ...  liveness  loudness  mode  \
# 0        85267   0.106          0.029200  ...    0.1790   -22.507     0
# 1       231173   0.645          0.000000  ...    0.2460    -9.200     1
# 2       292880   0.889          0.011400  ...    0.2170    -5.175     1
# 3       271133   0.863          0.000006  ...    0.0699    -7.823     1
# 4       284427   0.765          0.000008  ...    0.2130    -8.558     1
#
#    speechiness    tempo  time_signature  \
# 0       0.0448   46.718               4
# 1       0.0376   93.050               4
# 2       0.0364  133.519               4
# 3       0.0380  131.196               4
# 4       0.0413  106.463               4
#
#                                           track_href            type  \
# 0  https://api.spotify.com/v1/tracks/4tHqQMWSqmL6...  audio_features
# 1  https://api.spotify.com/v1/tracks/38xhBO2AKrJn...  audio_features
# 2  https://api.spotify.com/v1/tracks/57bgtoPSgt23...  audio_features
# 3  https://api.spotify.com/v1/tracks/5pKJtX4wBeby...  audio_features
# 4  https://api.spotify.com/v1/tracks/6gZVQvQZOFpz...  audio_features
#
#                                     uri valence
# 0  spotify:track:4tHqQMWSqmL6YjXwsqthDI   0.800
# 1  spotify:track:38xhBO2AKrJnjdjVnhJES6   0.677
# 2  spotify:track:57bgtoPSgt236HzfBOd8kj   0.257
# 3  spotify:track:5pKJtX4wBeby9qIfFhyOJj   0.776
# 4  spotify:track:6gZVQvQZOFpzIy3HblJ20F   0.644
#
# [5 rows x 21 columns]

# %%
# Drop irrelevant columns
df1990 = df90.drop(['analysis_url', 'track_href', 'type', 'uri'], axis=1)
df1990.head()
# Out:
#                         track                        artist  popularity  \
# 0          Carol of the Bells  Mykola Dmytrovych Leontovych          79
# 1              This Christmas                Donny Hathaway          78
# 2               Thunderstruck                         AC/DC          81
# 3  Don't Go Breaking My Heart                    Elton John          69
# 4              Man in the Box               Alice In Chains          71
#
#                        id  acousticness  danceability  duration_ms  energy  \
# 0  4tHqQMWSqmL6YjXwsqthDI      0.994000         0.418        85267   0.106
# 1  38xhBO2AKrJnjdjVnhJES6      0.292000         0.634       231173   0.645
# 2  57bgtoPSgt236HzfBOd8kj      0.000147         0.501       292880   0.889
# 3  5pKJtX4wBeby9qIfFhyOJj      0.177000         0.742       271133   0.863
# 4  6gZVQvQZOFpzIy3HblJ20F      0.002290         0.346       284427   0.765
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.029200    8    0.1790   -22.507     0       0.0448   46.718
# 1          0.000000    5    0.2460    -9.200     1       0.0376   93.050
# 2          0.011400    4    0.2170    -5.175     1       0.0364  133.519
# 3          0.000006    5    0.0699    -7.823     1       0.0380  131.196
# 4          0.000008    8    0.2130    -8.558     1       0.0413  106.463
#
#    time_signature  valence
# 0               4    0.800
# 1               4    0.677
# 2               4    0.257
# 3               4    0.776
# 4               4    0.644

# %%
# Check for duplicates
df1990.nunique()
# Out:
# track                966
# artist               425
# popularity            47
# id                  1000
# acousticness         782
# danceability         508
# duration_ms          965
# energy               634
# instrumentalness     652
# key                   12
# liveness             559
# loudness             965
# mode                   2
# speechiness          484
# tempo                992
# time_signature         4
# valence              623
# dtype: int64

# %%
# Send to CSV
df1990.to_csv("spotify1990.csv")

# %% [markdown]
# ### 1991

# %%
# Lists to store data
track_name = []
artist = []
track_id = []
popularity = []

# %%
# Loop through general track info
for i in range(0, 1000, 50):
    year_1991 = sp.search(q='year:1991', type='track', limit=50, offset=i)
    for i, a in enumerate(year_1991['tracks']['items']):
        
        track_name.append(a['name'])
        artist.append(a['artists'][0]['name'])
        popularity.append(a['popularity'])
        track_id.append(a['id'])

len(track_name)
# Out:
# 1000

# %%
df_1991 = pd.DataFrame({'track':track_name, 'artist':artist, 'popularity':popularity, 'id':track_id})
df_1991.head()
# Out:
#                      track                 artist  popularity  \
# 0            Enter Sandman              Metallica          74
# 1  Smells Like Teen Spirit                Nirvana          74
# 2         Under the Bridge  Red Hot Chili Peppers          81
# 3          Come As You Are                Nirvana          72
# 4     Nothing Else Matters              Metallica          69
#
#                        id
# 0  5BIMPccDwShpXq784RJlJp
# 1  5ghIJDpPoe3CfHMGu71E6T
# 2  3d9DChrdc6BOeFsbrZ3Is0
# 3  4P5KoWXOxwuobLmHXLMobV
# 4  10igKaIKsSB6ZnWxPxPvKO

# %%
# Get track feautured information

# Lists to match data to df_1991
new91 = []
limitsize = 100
none91 = 0

# %%
# Get track feautured information
for i in range(0, len(df_1991['id']), limitsize):
    feat_91 = df_1991['id'][i:i+limitsize]
    res_91 = sp.audio_features(feat_91)
    for i, a in enumerate(res_91):
        if a == None:
            none91 = none91 + 1
        else:
            new91.append(a)
            
len(new91)
# Out:
# 1000

# %%
info91 = pd.DataFrame.from_dict(new91, orient='columns')
info91.head()
# Out:
#    acousticness                                       analysis_url  \
# 0      0.002060  https://api.spotify.com/v1/audio-analysis/5BIM...
# 1      0.000025  https://api.spotify.com/v1/audio-analysis/5ghI...
# 2      0.057600  https://api.spotify.com/v1/audio-analysis/3d9D...
# 3      0.000160  https://api.spotify.com/v1/audio-analysis/4P5K...
# 4      0.050500  https://api.spotify.com/v1/audio-analysis/10ig...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.579       331573   0.824  5BIMPccDwShpXq784RJlJp
# 1         0.502       301920   0.912  5ghIJDpPoe3CfHMGu71E6T
# 2         0.559       264307   0.345  3d9DChrdc6BOeFsbrZ3Is0
# 3         0.500       218920   0.824  4P5KoWXOxwuobLmHXLMobV
# 4         0.558       388733   0.364  10igKaIKsSB6ZnWxPxPvKO
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.009030    6    0.0590    -8.710     0       0.0300  123.331
# 1          0.000173    1    0.1060    -4.556     1       0.0564  116.761
# 2          0.000105    4    0.1410   -13.496     1       0.0459   84.581
# 3          0.001610    4    0.0916    -5.846     0       0.0388  120.125
# 4          0.000005    4    0.0753   -11.258     0       0.0265  142.171
#
#    time_signature                                         track_href  \
# 0               4  https://api.spotify.com/v1/tracks/5BIMPccDwShp...
# 1               4  https://api.spotify.com/v1/tracks/5ghIJDpPoe3C...
# 2               4  https://api.spotify.com/v1/tracks/3d9DChrdc6BO...
# 3               4  https://api.spotify.com/v1/tracks/4P5KoWXOxwuo...
# 4               3  https://api.spotify.com/v1/tracks/10igKaIKsSB6...
#
#              type                                   uri  valence
# 0  audio_features  spotify:track:5BIMPccDwShpXq784RJlJp    0.635
# 1  audio_features  spotify:track:5ghIJDpPoe3CfHMGu71E6T    0.720
# 2  audio_features  spotify:track:3d9DChrdc6BOeFsbrZ3Is0    0.458
# 3  audio_features  spotify:track:4P5KoWXOxwuobLmHXLMobV    0.539
# 4  audio_features  spotify:track:10igKaIKsSB6ZnWxPxPvKO    0.170

# %%
# Join both datasets
df91 = pd.merge(df_1991, info91, on='id', how='inner')
df91.head()
# Out:
#                      track                 artist  popularity  \
# 0            Enter Sandman              Metallica          74
# 1  Smells Like Teen Spirit                Nirvana          74
# 2         Under the Bridge  Red Hot Chili Peppers          81
# 3          Come As You Are                Nirvana          72
# 4     Nothing Else Matters              Metallica          69
#
#                        id  acousticness  \
# 0  5BIMPccDwShpXq784RJlJp      0.002060
# 1  5ghIJDpPoe3CfHMGu71E6T      0.000025
# 2  3d9DChrdc6BOeFsbrZ3Is0      0.057600
# 3  4P5KoWXOxwuobLmHXLMobV      0.000160
# 4  10igKaIKsSB6ZnWxPxPvKO      0.050500
#
#                                         analysis_url  danceability  \
# 0  https://api.spotify.com/v1/audio-analysis/5BIM...         0.579
# 1  https://api.spotify.com/v1/audio-analysis/5ghI...         0.502
# 2  https://api.spotify.com/v1/audio-analysis/3d9D...         0.559
# 3  https://api.spotify.com/v1/audio-analysis/4P5K...         0.500
# 4  https://api.spotify.com/v1/audio-analysis/10ig...         0.558
#
#    duration_ms  energy  instrumentalness  ...  liveness  loudness  mode  \
# 0       331573   0.824          0.009030  ...    0.0590    -8.710     0
# 1       301920   0.912          0.000173  ...    0.1060    -4.556     1
# 2       264307   0.345          0.000105  ...    0.1410   -13.496     1
# 3       218920   0.824          0.001610  ...    0.0916    -5.846     0
# 4       388733   0.364          0.000005  ...    0.0753   -11.258     0
#
#    speechiness    tempo  time_signature  \
# 0       0.0300  123.331               4
# 1       0.0564  116.761               4
# 2       0.0459   84.581               4
# 3       0.0388  120.125               4
# 4       0.0265  142.171               3
#
#                                           track_href            type  \
# 0  https://api.spotify.com/v1/tracks/5BIMPccDwShp...  audio_features
# 1  https://api.spotify.com/v1/tracks/5ghIJDpPoe3C...  audio_features
# 2  https://api.spotify.com/v1/tracks/3d9DChrdc6BO...  audio_features
# 3  https://api.spotify.com/v1/tracks/4P5KoWXOxwuo...  audio_features
# 4  https://api.spotify.com/v1/tracks/10igKaIKsSB6...  audio_features
#
#                                     uri valence
# 0  spotify:track:5BIMPccDwShpXq784RJlJp   0.635
# 1  spotify:track:5ghIJDpPoe3CfHMGu71E6T   0.720
# 2  spotify:track:3d9DChrdc6BOeFsbrZ3Is0   0.458
# 3  spotify:track:4P5KoWXOxwuobLmHXLMobV   0.539
# 4  spotify:track:10igKaIKsSB6ZnWxPxPvKO   0.170
#
# [5 rows x 21 columns]

# %%
# Drop irrelevant columns
df1991 = df91.drop(['analysis_url', 'track_href', 'type', 'uri'], axis=1)
df1991.head()
# Out:
#                      track                 artist  popularity  \
# 0            Enter Sandman              Metallica          74
# 1  Smells Like Teen Spirit                Nirvana          74
# 2         Under the Bridge  Red Hot Chili Peppers          81
# 3          Come As You Are                Nirvana          72
# 4     Nothing Else Matters              Metallica          69
#
#                        id  acousticness  danceability  duration_ms  energy  \
# 0  5BIMPccDwShpXq784RJlJp      0.002060         0.579       331573   0.824
# 1  5ghIJDpPoe3CfHMGu71E6T      0.000025         0.502       301920   0.912
# 2  3d9DChrdc6BOeFsbrZ3Is0      0.057600         0.559       264307   0.345
# 3  4P5KoWXOxwuobLmHXLMobV      0.000160         0.500       218920   0.824
# 4  10igKaIKsSB6ZnWxPxPvKO      0.050500         0.558       388733   0.364
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.009030    6    0.0590    -8.710     0       0.0300  123.331
# 1          0.000173    1    0.1060    -4.556     1       0.0564  116.761
# 2          0.000105    4    0.1410   -13.496     1       0.0459   84.581
# 3          0.001610    4    0.0916    -5.846     0       0.0388  120.125
# 4          0.000005    4    0.0753   -11.258     0       0.0265  142.171
#
#    time_signature  valence
# 0               4    0.635
# 1               4    0.720
# 2               4    0.458
# 3               4    0.539
# 4               3    0.170

# %%
# Check for duplicates
df1991.nunique()
# Out:
# track                961
# artist               375
# popularity            47
# id                  1000
# acousticness         764
# danceability         530
# duration_ms          944
# energy               583
# instrumentalness     646
# key                   12
# liveness             556
# loudness             941
# mode                   2
# speechiness          501
# tempo                967
# time_signature         5
# valence              603
# dtype: int64

# %%
# Send to CSV
df1991.to_csv("spotify1991.csv")

# %% [markdown]
# ### 1992

# %%
# Lists to store data
track_name = []
artist = []
track_id = []
popularity = []

# %%
# Loop through general track info
for i in range(0, 1000, 50):
    year_1992 = sp.search(q='year:1992', type='track', limit=50, offset=i)
    for i, a in enumerate(year_1992['tracks']['items']):
        
        track_name.append(a['name'])
        artist.append(a['artists'][0]['name'])
        popularity.append(a['popularity'])
        track_id.append(a['id'])

len(track_name)
# Out:
# 1000

# %%
df_1992 = pd.DataFrame({'track':track_name, 'artist':artist, 'popularity':popularity, 'id':track_id})
df_1992.head()
# Out:
#                  track                    artist  popularity  \
# 0     Jingle Bell Rock               Bobby Helms          87
# 1    It Was A Good Day                  Ice Cube          74
# 2  Killing In The Name  Rage Against The Machine          78
# 3              No Rain               Blind Melon          73
# 4          Jump Around             House Of Pain          74
#
#                        id
# 0  3hBXvHLlTHvnbwrPbeoyAj
# 1  2qOm7ukLyHUXWyR4ZWLwxA
# 2  59WN2psjkt1tyaxjspN8fp
# 3  6txWz9UapYHVxEd7dDIHXT
# 4  3TZwjdclvWt7iPJUnMpgcs

# %%
# Get track feautured information

# Lists to match data to df_1992
new92 = []
limitsize = 100
none92 = 0

# %%
# Get track feautured information
for i in range(0, len(df_1992['id']), limitsize):
    feat_92 = df_1992['id'][i:i+limitsize]
    res_92 = sp.audio_features(feat_92)
    for i, a in enumerate(res_92):
        if a == None:
            none92 = none92 + 1
        else:
            new92.append(a)

len(new92)
# Out:
# 1000

# %%
info92 = pd.DataFrame.from_dict(new92, orient='columns')
info92.head()
# Out:
#    acousticness                                       analysis_url  \
# 0        0.6430  https://api.spotify.com/v1/audio-analysis/3hBX...
# 1        0.3300  https://api.spotify.com/v1/audio-analysis/2qOm...
# 2        0.0266  https://api.spotify.com/v1/audio-analysis/59WN...
# 3        0.6190  https://api.spotify.com/v1/audio-analysis/6txW...
# 4        0.0113  https://api.spotify.com/v1/audio-analysis/3TZw...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.754       130973   0.424  3hBXvHLlTHvnbwrPbeoyAj
# 1         0.798       260000   0.744  2qOm7ukLyHUXWyR4ZWLwxA
# 2         0.466       313573   0.833  59WN2psjkt1tyaxjspN8fp
# 3         0.389       217107   0.476  6txWz9UapYHVxEd7dDIHXT
# 4         0.854       214947   0.710  3TZwjdclvWt7iPJUnMpgcs
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.000000    2    0.0652    -8.463     1       0.0363  119.705
# 1          0.000106    7    0.2920    -5.328     0       0.1360   82.356
# 2          0.000000    7    0.0327    -4.215     1       0.3040   88.785
# 3          0.000051    9    0.2550    -9.342     1       0.0316  148.117
# 4          0.000087    4    0.1660    -6.320     0       0.0793  106.894
#
#    time_signature                                         track_href  \
# 0               4  https://api.spotify.com/v1/tracks/3hBXvHLlTHvn...
# 1               4  https://api.spotify.com/v1/tracks/2qOm7ukLyHUX...
# 2               4  https://api.spotify.com/v1/tracks/59WN2psjkt1t...
# 3               4  https://api.spotify.com/v1/tracks/6txWz9UapYHV...
# 4               4  https://api.spotify.com/v1/tracks/3TZwjdclvWt7...
#
#              type                                   uri  valence
# 0  audio_features  spotify:track:3hBXvHLlTHvnbwrPbeoyAj    0.806
# 1  audio_features  spotify:track:2qOm7ukLyHUXWyR4ZWLwxA    0.794
# 2  audio_features  spotify:track:59WN2psjkt1tyaxjspN8fp    0.661
# 3  audio_features  spotify:track:6txWz9UapYHVxEd7dDIHXT    0.566
# 4  audio_features  spotify:track:3TZwjdclvWt7iPJUnMpgcs    0.818

# %%
# Join both datasets
df92 = pd.merge(df_1992, info92, on='id', how='inner')
df92.head()
# Out:
#                  track                    artist  popularity  \
# 0     Jingle Bell Rock               Bobby Helms          87
# 1    It Was A Good Day                  Ice Cube          74
# 2  Killing In The Name  Rage Against The Machine          78
# 3              No Rain               Blind Melon          73
# 4          Jump Around             House Of Pain          74
#
#                        id  acousticness  \
# 0  3hBXvHLlTHvnbwrPbeoyAj        0.6430
# 1  2qOm7ukLyHUXWyR4ZWLwxA        0.3300
# 2  59WN2psjkt1tyaxjspN8fp        0.0266
# 3  6txWz9UapYHVxEd7dDIHXT        0.6190
# 4  3TZwjdclvWt7iPJUnMpgcs        0.0113
#
#                                         analysis_url  danceability  \
# 0  https://api.spotify.com/v1/audio-analysis/3hBX...         0.754
# 1  https://api.spotify.com/v1/audio-analysis/2qOm...         0.798
# 2  https://api.spotify.com/v1/audio-analysis/59WN...         0.466
# 3  https://api.spotify.com/v1/audio-analysis/6txW...         0.389
# 4  https://api.spotify.com/v1/audio-analysis/3TZw...         0.854
#
#    duration_ms  energy  instrumentalness  ...  liveness  loudness  mode  \
# 0       130973   0.424          0.000000  ...    0.0652    -8.463     1
# 1       260000   0.744          0.000106  ...    0.2920    -5.328     0
# 2       313573   0.833          0.000000  ...    0.0327    -4.215     1
# 3       217107   0.476          0.000051  ...    0.2550    -9.342     1
# 4       214947   0.710          0.000087  ...    0.1660    -6.320     0
#
#    speechiness    tempo  time_signature  \
# 0       0.0363  119.705               4
# 1       0.1360   82.356               4
# 2       0.3040   88.785               4
# 3       0.0316  148.117               4
# 4       0.0793  106.894               4
#
#                                           track_href            type  \
# 0  https://api.spotify.com/v1/tracks/3hBXvHLlTHvn...  audio_features
# 1  https://api.spotify.com/v1/tracks/2qOm7ukLyHUX...  audio_features
# 2  https://api.spotify.com/v1/tracks/59WN2psjkt1t...  audio_features
# 3  https://api.spotify.com/v1/tracks/6txWz9UapYHV...  audio_features
# 4  https://api.spotify.com/v1/tracks/3TZwjdclvWt7...  audio_features
#
#                                     uri valence
# 0  spotify:track:3hBXvHLlTHvnbwrPbeoyAj   0.806
# 1  spotify:track:2qOm7ukLyHUXWyR4ZWLwxA   0.794
# 2  spotify:track:59WN2psjkt1tyaxjspN8fp   0.661
# 3  spotify:track:6txWz9UapYHVxEd7dDIHXT   0.566
# 4  spotify:track:3TZwjdclvWt7iPJUnMpgcs   0.818
#
# [5 rows x 21 columns]

# %%
# Drop irrelevant columns
df1992 = df92.drop(['analysis_url', 'track_href', 'type', 'uri'], axis=1)
df1992.head()
# Out:
#                  track                    artist  popularity  \
# 0     Jingle Bell Rock               Bobby Helms          87
# 1    It Was A Good Day                  Ice Cube          74
# 2  Killing In The Name  Rage Against The Machine          78
# 3              No Rain               Blind Melon          73
# 4          Jump Around             House Of Pain          74
#
#                        id  acousticness  danceability  duration_ms  energy  \
# 0  3hBXvHLlTHvnbwrPbeoyAj        0.6430         0.754       130973   0.424
# 1  2qOm7ukLyHUXWyR4ZWLwxA        0.3300         0.798       260000   0.744
# 2  59WN2psjkt1tyaxjspN8fp        0.0266         0.466       313573   0.833
# 3  6txWz9UapYHVxEd7dDIHXT        0.6190         0.389       217107   0.476
# 4  3TZwjdclvWt7iPJUnMpgcs        0.0113         0.854       214947   0.710
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.000000    2    0.0652    -8.463     1       0.0363  119.705
# 1          0.000106    7    0.2920    -5.328     0       0.1360   82.356
# 2          0.000000    7    0.0327    -4.215     1       0.3040   88.785
# 3          0.000051    9    0.2550    -9.342     1       0.0316  148.117
# 4          0.000087    4    0.1660    -6.320     0       0.0793  106.894
#
#    time_signature  valence
# 0               4    0.806
# 1               4    0.794
# 2               4    0.661
# 3               4    0.566
# 4               4    0.818

# %%
# Check for duplicates
df1992.nunique()
# Out:
# track                981
# artist               416
# popularity            44
# id                  1000
# acousticness         795
# danceability         509
# duration_ms          969
# energy               591
# instrumentalness     678
# key                   12
# liveness             549
# loudness             952
# mode                   2
# speechiness          513
# tempo                992
# time_signature         4
# valence              599
# dtype: int64

# %%
# Send to CSV
df1992.to_csv("spotify1992.csv")

# %% [markdown]
# ### 1993

# %%
# Lists to store data
track_name = []
artist = []
track_id = []
popularity = []

# %%
# Loop through general track info
for i in range(0, 1000, 50):
    year_1993 = sp.search(q='year:1993', type='track', limit=50, offset=i)
    for i, a in enumerate(year_1993['tracks']['items']):
        
        track_name.append(a['name'])
        artist.append(a['artists'][0]['name'])
        popularity.append(a['popularity'])
        track_id.append(a['id'])

len(track_name)
# Out:
# 1000

# %%
df_1993 = pd.DataFrame({'track':track_name, 'artist':artist, 'popularity':popularity, 'id':track_id})
df_1993.head()
# Out:
#                                  track          artist  popularity  \
# 0                                Creep       Radiohead          82
# 1                            Mr. Jones  Counting Crows          76
# 2  Gin And Juice (feat. Dat Nigga Daz)      Snoop Dogg          73
# 3                     Heart-Shaped Box         Nirvana          74
# 4                           C.R.E.A.M.    Wu-Tang Clan          73
#
#                        id
# 0  6b2oQwSGFkzsMtQruIWm2p
# 1  5DiXcVovI0FcY2s0icWWUu
# 2  0WKYRFtH6KKbaNWjsxqm70
# 3  11LmqTE2naFULdEP94AUBa
# 4  119c93MHjrDLJTApCVGpvx

# %%
# Get track feautured information

# Lists to match data to df_1993
new93 = []
limitsize = 100
none93 = 0

# %%
# Get track feautured information
for i in range(0, len(df_1993['id']), limitsize):
    feat_93 = df_1993['id'][i:i+limitsize]
    res_93 = sp.audio_features(feat_93)
    for i, a in enumerate(res_93):
        if a == None:
            none93 = none93 + 1
        else:
            new93.append(a)

len(new93)
# Out:
# 1000

# %%
info93 = pd.DataFrame.from_dict(new93, orient='columns')
info93.head()
# Out:
#    acousticness                                       analysis_url  \
# 0        0.0102  https://api.spotify.com/v1/audio-analysis/6b2o...
# 1        0.1830  https://api.spotify.com/v1/audio-analysis/5DiX...
# 2        0.0285  https://api.spotify.com/v1/audio-analysis/0WKY...
# 3        0.1990  https://api.spotify.com/v1/audio-analysis/11Lm...
# 4        0.5700  https://api.spotify.com/v1/audio-analysis/119c...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.515       238640   0.430  6b2oQwSGFkzsMtQruIWm2p
# 1         0.578       272293   0.817  5DiXcVovI0FcY2s0icWWUu
# 2         0.549       211493   0.853  0WKYRFtH6KKbaNWjsxqm70
# 3         0.256       281160   0.641  11LmqTE2naFULdEP94AUBa
# 4         0.479       252187   0.549  119c93MHjrDLJTApCVGpvx
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.000141    7    0.1290    -9.935     1       0.0369   91.841
# 1          0.000003    0    0.2850    -6.542     1       0.0363  141.621
# 2          0.000296    7    0.6180    -4.293     1       0.1880   94.695
# 3          0.032900    1    0.0853   -10.283     1       0.0552  203.006
# 4          0.023900   11    0.1270   -10.551     0       0.3730  180.985
#
#    time_signature                                         track_href  \
# 0               4  https://api.spotify.com/v1/tracks/6b2oQwSGFkzs...
# 1               4  https://api.spotify.com/v1/tracks/5DiXcVovI0Fc...
# 2               4  https://api.spotify.com/v1/tracks/0WKYRFtH6KKb...
# 3               4  https://api.spotify.com/v1/tracks/11LmqTE2naFU...
# 4               4  https://api.spotify.com/v1/tracks/119c93MHjrDL...
#
#              type                                   uri  valence
# 0  audio_features  spotify:track:6b2oQwSGFkzsMtQruIWm2p    0.104
# 1  audio_features  spotify:track:5DiXcVovI0FcY2s0icWWUu    0.726
# 2  audio_features  spotify:track:0WKYRFtH6KKbaNWjsxqm70    0.346
# 3  audio_features  spotify:track:11LmqTE2naFULdEP94AUBa    0.382
# 4  audio_features  spotify:track:119c93MHjrDLJTApCVGpvx    0.576

# %%
# Join both datasets
df93 = pd.merge(df_1993, info93, on='id', how='inner')
df93.head()
# Out:
#                                  track          artist  popularity  \
# 0                                Creep       Radiohead          82
# 1                            Mr. Jones  Counting Crows          76
# 2  Gin And Juice (feat. Dat Nigga Daz)      Snoop Dogg          73
# 3                     Heart-Shaped Box         Nirvana          74
# 4                           C.R.E.A.M.    Wu-Tang Clan          73
#
#                        id  acousticness  \
# 0  6b2oQwSGFkzsMtQruIWm2p        0.0102
# 1  5DiXcVovI0FcY2s0icWWUu        0.1830
# 2  0WKYRFtH6KKbaNWjsxqm70        0.0285
# 3  11LmqTE2naFULdEP94AUBa        0.1990
# 4  119c93MHjrDLJTApCVGpvx        0.5700
#
#                                         analysis_url  danceability  \
# 0  https://api.spotify.com/v1/audio-analysis/6b2o...         0.515
# 1  https://api.spotify.com/v1/audio-analysis/5DiX...         0.578
# 2  https://api.spotify.com/v1/audio-analysis/0WKY...         0.549
# 3  https://api.spotify.com/v1/audio-analysis/11Lm...         0.256
# 4  https://api.spotify.com/v1/audio-analysis/119c...         0.479
#
#    duration_ms  energy  instrumentalness  ...  liveness  loudness  mode  \
# 0       238640   0.430          0.000141  ...    0.1290    -9.935     1
# 1       272293   0.817          0.000003  ...    0.2850    -6.542     1
# 2       211493   0.853          0.000296  ...    0.6180    -4.293     1
# 3       281160   0.641          0.032900  ...    0.0853   -10.283     1
# 4       252187   0.549          0.023900  ...    0.1270   -10.551     0
#
#    speechiness    tempo  time_signature  \
# 0       0.0369   91.841               4
# 1       0.0363  141.621               4
# 2       0.1880   94.695               4
# 3       0.0552  203.006               4
# 4       0.3730  180.985               4
#
#                                           track_href            type  \
# 0  https://api.spotify.com/v1/tracks/6b2oQwSGFkzs...  audio_features
# 1  https://api.spotify.com/v1/tracks/5DiXcVovI0Fc...  audio_features
# 2  https://api.spotify.com/v1/tracks/0WKYRFtH6KKb...  audio_features
# 3  https://api.spotify.com/v1/tracks/11LmqTE2naFU...  audio_features
# 4  https://api.spotify.com/v1/tracks/119c93MHjrDL...  audio_features
#
#                                     uri valence
# 0  spotify:track:6b2oQwSGFkzsMtQruIWm2p   0.104
# 1  spotify:track:5DiXcVovI0FcY2s0icWWUu   0.726
# 2  spotify:track:0WKYRFtH6KKbaNWjsxqm70   0.346
# 3  spotify:track:11LmqTE2naFULdEP94AUBa   0.382
# 4  spotify:track:119c93MHjrDLJTApCVGpvx   0.576
#
# [5 rows x 21 columns]

# %%
# Drop irrelevant columns
df1993 = df93.drop(['analysis_url', 'track_href', 'type', 'uri'], axis=1)
df1993.head()
# Out:
#                                  track          artist  popularity  \
# 0                                Creep       Radiohead          82
# 1                            Mr. Jones  Counting Crows          76
# 2  Gin And Juice (feat. Dat Nigga Daz)      Snoop Dogg          73
# 3                     Heart-Shaped Box         Nirvana          74
# 4                           C.R.E.A.M.    Wu-Tang Clan          73
#
#                        id  acousticness  danceability  duration_ms  energy  \
# 0  6b2oQwSGFkzsMtQruIWm2p        0.0102         0.515       238640   0.430
# 1  5DiXcVovI0FcY2s0icWWUu        0.1830         0.578       272293   0.817
# 2  0WKYRFtH6KKbaNWjsxqm70        0.0285         0.549       211493   0.853
# 3  11LmqTE2naFULdEP94AUBa        0.1990         0.256       281160   0.641
# 4  119c93MHjrDLJTApCVGpvx        0.5700         0.479       252187   0.549
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.000141    7    0.1290    -9.935     1       0.0369   91.841
# 1          0.000003    0    0.2850    -6.542     1       0.0363  141.621
# 2          0.000296    7    0.6180    -4.293     1       0.1880   94.695
# 3          0.032900    1    0.0853   -10.283     1       0.0552  203.006
# 4          0.023900   11    0.1270   -10.551     0       0.3730  180.985
#
#    time_signature  valence
# 0               4    0.104
# 1               4    0.726
# 2               4    0.346
# 3               4    0.382
# 4               4    0.576

# %%
# Check for duplicates
df1993.nunique()
# Out:
# track                973
# artist               436
# popularity            44
# id                  1000
# acousticness         782
# danceability         510
# duration_ms          957
# energy               588
# instrumentalness     634
# key                   12
# liveness             545
# loudness             947
# mode                   2
# speechiness          513
# tempo                976
# time_signature         4
# valence              599
# dtype: int64

# %%
# Send to CSV
df1993.to_csv("spotify1993.csv")

# %% [markdown]
# ### 1994

# %%
# Lists to store data
track_name = []
artist = []
track_id = []
popularity = []

# %%
# Loop through general track info
for i in range(0, 1000, 50):
    year_1994 = sp.search(q='year:1994', type='track', limit=50, offset=i)
    for i, a in enumerate(year_1994['tracks']['items']):
        
        track_name.append(a['name'])
        artist.append(a['artists'][0]['name'])
        popularity.append(a['popularity'])
        track_id.append(a['id'])

len(track_name)
# Out:
# 1000

# %%
df_1994 = pd.DataFrame({'track':track_name, 'artist':artist, 'popularity':popularity, 'id':track_id})
df_1994.head()
# Out:
#                                                track         artist  \
# 0                    All I Want for Christmas Is You   Mariah Carey
# 1  Let It Snow! Let It Snow! Let It Snow! (with T...  Frank Sinatra
# 2                  Christmas (Baby Please Come Home)   Mariah Carey
# 3                                       O Holy Night   Mariah Carey
# 4                                    Say It Ain't So         Weezer
#
#    popularity                      id
# 0          93  0bYg9bo50gSsH3LtXe2SQn
# 1          87  4kKdvXD0ez7jp1296JmAts
# 2          83  3PIDciSFdrQxSQSihim3hN
# 3          77  3B7FO3kJ5kv3mX7yiaB7sT
# 4          73  6VoIBz0VhCyz7OdEoRYDiA

# %%
# Get track feautured information

# Lists to match data to df_1994
new94 = []
limitsize = 100
none94 = 0

# %%
# Get track feautured information
for i in range(0, len(df_1994['id']), limitsize):
    feat_94 = df_1994['id'][i:i+limitsize]
    res_94 = sp.audio_features(feat_94)
    for i, a in enumerate(res_94):
        if a == None:
            none94 = none94 + 1
        else:
            new94.append(a)

len(new94)
# Out:
# 1000

# %%
info94 = pd.DataFrame.from_dict(new94, orient='columns')
info94.head()
# Out:
#    acousticness                                       analysis_url  \
# 0       0.16400  https://api.spotify.com/v1/audio-analysis/0bYg...
# 1       0.90300  https://api.spotify.com/v1/audio-analysis/4kKd...
# 2       0.02200  https://api.spotify.com/v1/audio-analysis/3PID...
# 3       0.36700  https://api.spotify.com/v1/audio-analysis/3B7F...
# 4       0.00737  https://api.spotify.com/v1/audio-analysis/6VoI...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.335       241107   0.625  0bYg9bo50gSsH3LtXe2SQn
# 1         0.653       155453   0.259  4kKdvXD0ez7jp1296JmAts
# 2         0.566       153240   0.782  3PIDciSFdrQxSQSihim3hN
# 3         0.362       266933   0.505  3B7FO3kJ5kv3mX7yiaB7sT
# 4         0.634       258827   0.551  6VoIBz0VhCyz7OdEoRYDiA
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.000000    7    0.0708    -7.462     1       0.0386  150.277
# 1          0.000000    2    0.3620   -13.336     1       0.0595  142.157
# 2          0.000000    3    0.1090    -7.444     1       0.0311  127.160
# 3          0.000006    4    0.1540    -7.208     1       0.0287  174.066
# 4          0.000018    3    0.0700    -7.136     1       0.0352  151.779
#
#    time_signature                                         track_href  \
# 0               4  https://api.spotify.com/v1/tracks/0bYg9bo50gSs...
# 1               4  https://api.spotify.com/v1/tracks/4kKdvXD0ez7j...
# 2               4  https://api.spotify.com/v1/tracks/3PIDciSFdrQx...
# 3               3  https://api.spotify.com/v1/tracks/3B7FO3kJ5kv3...
# 4               4  https://api.spotify.com/v1/tracks/6VoIBz0VhCyz...
#
#              type                                   uri  valence
# 0  audio_features  spotify:track:0bYg9bo50gSsH3LtXe2SQn    0.346
# 1  audio_features  spotify:track:4kKdvXD0ez7jp1296JmAts    0.835
# 2  audio_features  spotify:track:3PIDciSFdrQxSQSihim3hN    0.697
# 3  audio_features  spotify:track:3B7FO3kJ5kv3mX7yiaB7sT    0.192
# 4  audio_features  spotify:track:6VoIBz0VhCyz7OdEoRYDiA    0.453

# %%
# Join both datasets
df94 = pd.merge(df_1994, info94, on='id', how='inner')
df94.head()
# Out:
#                                                track         artist  \
# 0                    All I Want for Christmas Is You   Mariah Carey
# 1  Let It Snow! Let It Snow! Let It Snow! (with T...  Frank Sinatra
# 2                  Christmas (Baby Please Come Home)   Mariah Carey
# 3                                       O Holy Night   Mariah Carey
# 4                                    Say It Ain't So         Weezer
#
#    popularity                      id  acousticness  \
# 0          93  0bYg9bo50gSsH3LtXe2SQn       0.16400
# 1          87  4kKdvXD0ez7jp1296JmAts       0.90300
# 2          83  3PIDciSFdrQxSQSihim3hN       0.02200
# 3          77  3B7FO3kJ5kv3mX7yiaB7sT       0.36700
# 4          73  6VoIBz0VhCyz7OdEoRYDiA       0.00737
#
#                                         analysis_url  danceability  \
# 0  https://api.spotify.com/v1/audio-analysis/0bYg...         0.335
# 1  https://api.spotify.com/v1/audio-analysis/4kKd...         0.653
# 2  https://api.spotify.com/v1/audio-analysis/3PID...         0.566
# 3  https://api.spotify.com/v1/audio-analysis/3B7F...         0.362
# 4  https://api.spotify.com/v1/audio-analysis/6VoI...         0.634
#
#    duration_ms  energy  instrumentalness  ...  liveness  loudness  mode  \
# 0       241107   0.625          0.000000  ...    0.0708    -7.462     1
# 1       155453   0.259          0.000000  ...    0.3620   -13.336     1
# 2       153240   0.782          0.000000  ...    0.1090    -7.444     1
# 3       266933   0.505          0.000006  ...    0.1540    -7.208     1
# 4       258827   0.551          0.000018  ...    0.0700    -7.136     1
#
#    speechiness    tempo  time_signature  \
# 0       0.0386  150.277               4
# 1       0.0595  142.157               4
# 2       0.0311  127.160               4
# 3       0.0287  174.066               3
# 4       0.0352  151.779               4
#
#                                           track_href            type  \
# 0  https://api.spotify.com/v1/tracks/0bYg9bo50gSs...  audio_features
# 1  https://api.spotify.com/v1/tracks/4kKdvXD0ez7j...  audio_features
# 2  https://api.spotify.com/v1/tracks/3PIDciSFdrQx...  audio_features
# 3  https://api.spotify.com/v1/tracks/3B7FO3kJ5kv3...  audio_features
# 4  https://api.spotify.com/v1/tracks/6VoIBz0VhCyz...  audio_features
#
#                                     uri valence
# 0  spotify:track:0bYg9bo50gSsH3LtXe2SQn   0.346
# 1  spotify:track:4kKdvXD0ez7jp1296JmAts   0.835
# 2  spotify:track:3PIDciSFdrQxSQSihim3hN   0.697
# 3  spotify:track:3B7FO3kJ5kv3mX7yiaB7sT   0.192
# 4  spotify:track:6VoIBz0VhCyz7OdEoRYDiA   0.453
#
# [5 rows x 21 columns]

# %%
# Drop irrelevant columns
df1994 = df94.drop(['analysis_url', 'track_href', 'type', 'uri'], axis=1)
df1994.head()
# Out:
#                                                track         artist  \
# 0                    All I Want for Christmas Is You   Mariah Carey
# 1  Let It Snow! Let It Snow! Let It Snow! (with T...  Frank Sinatra
# 2                  Christmas (Baby Please Come Home)   Mariah Carey
# 3                                       O Holy Night   Mariah Carey
# 4                                    Say It Ain't So         Weezer
#
#    popularity                      id  acousticness  danceability  \
# 0          93  0bYg9bo50gSsH3LtXe2SQn       0.16400         0.335
# 1          87  4kKdvXD0ez7jp1296JmAts       0.90300         0.653
# 2          83  3PIDciSFdrQxSQSihim3hN       0.02200         0.566
# 3          77  3B7FO3kJ5kv3mX7yiaB7sT       0.36700         0.362
# 4          73  6VoIBz0VhCyz7OdEoRYDiA       0.00737         0.634
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0       241107   0.625          0.000000    7    0.0708    -7.462     1
# 1       155453   0.259          0.000000    2    0.3620   -13.336     1
# 2       153240   0.782          0.000000    3    0.1090    -7.444     1
# 3       266933   0.505          0.000006    4    0.1540    -7.208     1
# 4       258827   0.551          0.000018    3    0.0700    -7.136     1
#
#    speechiness    tempo  time_signature  valence
# 0       0.0386  150.277               4    0.346
# 1       0.0595  142.157               4    0.835
# 2       0.0311  127.160               4    0.697
# 3       0.0287  174.066               3    0.192
# 4       0.0352  151.779               4    0.453

# %%
# Check for duplicates
df1994.nunique()
# Out:
# track                974
# artist               379
# popularity            47
# id                  1000
# acousticness         788
# danceability         540
# duration_ms          942
# energy               616
# instrumentalness     666
# key                   12
# liveness             535
# loudness             944
# mode                   2
# speechiness          514
# tempo                981
# time_signature         4
# valence              608
# dtype: int64

# %%
# Send to CSV
df1994.to_csv("spotify1994.csv")

# %% [markdown]
# ### 1995

# %%
# Lists to store data
track_name = []
artist = []
track_id = []
popularity = []

# %%
# Loop through general track info
for i in range(0, 1000, 50):
    year_1995 = sp.search(q='year:1995', type='track', limit=50, offset=i)
    for i, a in enumerate(year_1995['tracks']['items']):
        
        track_name.append(a['name'])
        artist.append(a['artists'][0]['name'])
        popularity.append(a['popularity'])
        track_id.append(a['id'])

len(track_name)
# Out:
# 1000

# %%
df_1995 = pd.DataFrame({'track':track_name, 'artist':artist, 'popularity':popularity, 'id':track_id})
df_1995.head()
# Out:
#                      track         artist  popularity                      id
# 0  Wonderwall - Remastered          Oasis          71  5wj4E6IsrVtn8IBJQOd0Cl
# 1       Gangsta's Paradise         Coolio          80  7lQWRAjyhTpCWFC0jmclT4
# 2          Check Yes Or No  George Strait          68  6iy4PoAuZBMvtrlDX4VxC7
# 3        Always Be My Baby   Mariah Carey          73  2aBxt229cbLDOvtL7Xbb9x
# 4            I Got 5 On It          Luniz          73  4IYKjN1DrYzxKXt0umJqsG

# %%
# Get track feautured information

# Lists to match data to df_1995
new95 = []
limitsize = 100
none95 = 0

# %%
# Get track feautured information
for i in range(0, len(df_1995['id']), limitsize):
    feat_95 = df_1995['id'][i:i+limitsize]
    res_95 = sp.audio_features(feat_95)
    for i, a in enumerate(res_95):
        if a == None:
            none95 = none95 + 1
        else:
            new95.append(a)

len(new95)
# Out:
# 1000

# %%
info95 = pd.DataFrame.from_dict(new95, orient='columns')
info95.head()
# Out:
#    acousticness                                       analysis_url  \
# 0      0.000453  https://api.spotify.com/v1/audio-analysis/5wj4...
# 1      0.065500  https://api.spotify.com/v1/audio-analysis/7lQW...
# 2      0.055100  https://api.spotify.com/v1/audio-analysis/6iy4...
# 3      0.457000  https://api.spotify.com/v1/audio-analysis/2aBx...
# 4      0.209000  https://api.spotify.com/v1/audio-analysis/4IYK...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.372       258733   0.865  5wj4E6IsrVtn8IBJQOd0Cl
# 1         0.647       240693   0.514  7lQWRAjyhTpCWFC0jmclT4
# 2         0.708       200667   0.524  6iy4PoAuZBMvtrlDX4VxC7
# 3         0.649       258133   0.531  2aBxt229cbLDOvtL7Xbb9x
# 4         0.600       253533   0.706  4IYKjN1DrYzxKXt0umJqsG
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.000000    2    0.2340    -4.918     1       0.0381  174.530
# 1          0.000000    8    0.3980   -10.050     1       0.0593   79.974
# 2          0.000003    5    0.0371   -12.644     1       0.0352  111.482
# 3          0.000000    4    0.2490    -8.335     1       0.0363   78.946
# 4          0.000000   10    0.1250    -7.899     0       0.3610  173.926
#
#    time_signature                                         track_href  \
# 0               4  https://api.spotify.com/v1/tracks/5wj4E6IsrVtn...
# 1               4  https://api.spotify.com/v1/tracks/7lQWRAjyhTpC...
# 2               4  https://api.spotify.com/v1/tracks/6iy4PoAuZBMv...
# 3               4  https://api.spotify.com/v1/tracks/2aBxt229cbLD...
# 4               4  https://api.spotify.com/v1/tracks/4IYKjN1DrYzx...
#
#              type                                   uri  valence
# 0  audio_features  spotify:track:5wj4E6IsrVtn8IBJQOd0Cl    0.478
# 1  audio_features  spotify:track:7lQWRAjyhTpCWFC0jmclT4    0.387
# 2  audio_features  spotify:track:6iy4PoAuZBMvtrlDX4VxC7    0.690
# 3  audio_features  spotify:track:2aBxt229cbLDOvtL7Xbb9x    0.488
# 4  audio_features  spotify:track:4IYKjN1DrYzxKXt0umJqsG    0.580

# %%
# Join both datasets
df95 = pd.merge(df_1995, info95, on='id', how='inner')
df95.head()
# Out:
#                      track         artist  popularity                      id  \
# 0  Wonderwall - Remastered          Oasis          71  5wj4E6IsrVtn8IBJQOd0Cl
# 1       Gangsta's Paradise         Coolio          80  7lQWRAjyhTpCWFC0jmclT4
# 2          Check Yes Or No  George Strait          68  6iy4PoAuZBMvtrlDX4VxC7
# 3        Always Be My Baby   Mariah Carey          73  2aBxt229cbLDOvtL7Xbb9x
# 4            I Got 5 On It          Luniz          73  4IYKjN1DrYzxKXt0umJqsG
#
#    acousticness                                       analysis_url  \
# 0      0.000453  https://api.spotify.com/v1/audio-analysis/5wj4...
# 1      0.065500  https://api.spotify.com/v1/audio-analysis/7lQW...
# 2      0.055100  https://api.spotify.com/v1/audio-analysis/6iy4...
# 3      0.457000  https://api.spotify.com/v1/audio-analysis/2aBx...
# 4      0.209000  https://api.spotify.com/v1/audio-analysis/4IYK...
#
#    danceability  duration_ms  energy  instrumentalness  ...  liveness  \
# 0         0.372       258733   0.865          0.000000  ...    0.2340
# 1         0.647       240693   0.514          0.000000  ...    0.3980
# 2         0.708       200667   0.524          0.000003  ...    0.0371
# 3         0.649       258133   0.531          0.000000  ...    0.2490
# 4         0.600       253533   0.706          0.000000  ...    0.1250
#
#    loudness  mode  speechiness    tempo  time_signature  \
# 0    -4.918     1       0.0381  174.530               4
# 1   -10.050     1       0.0593   79.974               4
# 2   -12.644     1       0.0352  111.482               4
# 3    -8.335     1       0.0363   78.946               4
# 4    -7.899     0       0.3610  173.926               4
#
#                                           track_href            type  \
# 0  https://api.spotify.com/v1/tracks/5wj4E6IsrVtn...  audio_features
# 1  https://api.spotify.com/v1/tracks/7lQWRAjyhTpC...  audio_features
# 2  https://api.spotify.com/v1/tracks/6iy4PoAuZBMv...  audio_features
# 3  https://api.spotify.com/v1/tracks/2aBxt229cbLD...  audio_features
# 4  https://api.spotify.com/v1/tracks/4IYKjN1DrYzx...  audio_features
#
#                                     uri valence
# 0  spotify:track:5wj4E6IsrVtn8IBJQOd0Cl   0.478
# 1  spotify:track:7lQWRAjyhTpCWFC0jmclT4   0.387
# 2  spotify:track:6iy4PoAuZBMvtrlDX4VxC7   0.690
# 3  spotify:track:2aBxt229cbLDOvtL7Xbb9x   0.488
# 4  spotify:track:4IYKjN1DrYzxKXt0umJqsG   0.580
#
# [5 rows x 21 columns]

# %%
# Drop irrelevant columns
df1995 = df95.drop(['analysis_url', 'track_href', 'type', 'uri'], axis=1)
df1995.head()
# Out:
#                      track         artist  popularity                      id  \
# 0  Wonderwall - Remastered          Oasis          71  5wj4E6IsrVtn8IBJQOd0Cl
# 1       Gangsta's Paradise         Coolio          80  7lQWRAjyhTpCWFC0jmclT4
# 2          Check Yes Or No  George Strait          68  6iy4PoAuZBMvtrlDX4VxC7
# 3        Always Be My Baby   Mariah Carey          73  2aBxt229cbLDOvtL7Xbb9x
# 4            I Got 5 On It          Luniz          73  4IYKjN1DrYzxKXt0umJqsG
#
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0      0.000453         0.372       258733   0.865          0.000000    2
# 1      0.065500         0.647       240693   0.514          0.000000    8
# 2      0.055100         0.708       200667   0.524          0.000003    5
# 3      0.457000         0.649       258133   0.531          0.000000    4
# 4      0.209000         0.600       253533   0.706          0.000000   10
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence
# 0    0.2340    -4.918     1       0.0381  174.530               4    0.478
# 1    0.3980   -10.050     1       0.0593   79.974               4    0.387
# 2    0.0371   -12.644     1       0.0352  111.482               4    0.690
# 3    0.2490    -8.335     1       0.0363   78.946               4    0.488
# 4    0.1250    -7.899     0       0.3610  173.926               4    0.580

# %%
# Check for duplicates
df1995.nunique()
# Out:
# track                987
# artist               438
# popularity            40
# id                  1000
# acousticness         781
# danceability         537
# duration_ms          951
# energy               603
# instrumentalness     610
# key                   12
# liveness             553
# loudness             959
# mode                   2
# speechiness          553
# tempo                990
# time_signature         4
# valence              636
# dtype: int64

# %%
# Send to CSV
df1995.to_csv("spotify1995.csv")

# %% [markdown]
# ### 2000

# %%
# Lists to store data
track_name = []
artist = []
track_id = []
popularity = []

# %%
# Loop through general track info
for i in range(0, 1000, 50):
    year_2000 = sp.search(q='year:2000', type='track', limit=50, offset=i)
    for i, a in enumerate(year_2000['tracks']['items']):
        
        track_name.append(a['name'])
        artist.append(a['artists'][0]['name'])
        popularity.append(a['popularity'])
        track_id.append(a['id'])

len(track_name)
# Out:
# 1000

# %%
df_2000 = pd.DataFrame({'track':track_name, 'artist':artist, 'popularity':popularity, 'id':track_id})
df_2000.head()
# Out:
#                  track              artist  popularity                      id
# 0           In the End         Linkin Park          83  60a0Rd6pjrkxjPbaKzXjfq
# 1           Kryptonite        3 Doors Down          77  6ZOBP3NvffbU4SZcrnt1k6
# 2  The Real Slim Shady              Eminem          80  3yfqSUWxFvZELEM4PmlwIR
# 3          Ms. Jackson             OutKast          77  0I3q5fE6wg7LIfHGngUTnV
# 4       This Christmas  Christina Aguilera          77  32h59T8q2SonUPJ006lyXt

# %%
# Get track feautured information

# Lists to match data to df_2000
new00 = []
limitsize = 100
none00 = 0

# %%
# Get track feautured information
for i in range(0, len(df_2000['id']), limitsize):
    feat_00 = df_2000['id'][i:i+limitsize]
    res_00 = sp.audio_features(feat_00)
    for i, a in enumerate(res_00):
        if a == None:
            none00 = none00 + 1
        else:
            new00.append(a)
 
len(new00)
# Out:
# 1000

# %%
info00 = pd.DataFrame.from_dict(new00, orient='columns')
info00.head()
# Out:
#    acousticness                                       analysis_url  \
# 0       0.00958  https://api.spotify.com/v1/audio-analysis/60a0...
# 1       0.00664  https://api.spotify.com/v1/audio-analysis/6ZOB...
# 2       0.03020  https://api.spotify.com/v1/audio-analysis/3yfq...
# 3       0.14200  https://api.spotify.com/v1/audio-analysis/0I3q...
# 4       0.06870  https://api.spotify.com/v1/audio-analysis/32h5...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.556       216880   0.864  60a0Rd6pjrkxjPbaKzXjfq
# 1         0.545       233933   0.865  6ZOBP3NvffbU4SZcrnt1k6
# 2         0.949       284200   0.661  3yfqSUWxFvZELEM4PmlwIR
# 3         0.843       270507   0.805  0I3q5fE6wg7LIfHGngUTnV
# 4         0.575       241507   0.744  32h59T8q2SonUPJ006lyXt
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.000000    3    0.2090    -5.870     0       0.0584  105.143
# 1          0.000011   11    0.1680    -5.708     0       0.0286   99.010
# 2          0.000000    5    0.0454    -4.244     0       0.0572  104.504
# 3          0.000000    4    0.0771    -5.946     0       0.2690   94.946
# 4          0.000000    1    0.0723    -5.466     1       0.0603  183.790
#
#    time_signature                                         track_href  \
# 0               4  https://api.spotify.com/v1/tracks/60a0Rd6pjrkx...
# 1               4  https://api.spotify.com/v1/tracks/6ZOBP3NvffbU...
# 2               4  https://api.spotify.com/v1/tracks/3yfqSUWxFvZE...
# 3               4  https://api.spotify.com/v1/tracks/0I3q5fE6wg7L...
# 4               4  https://api.spotify.com/v1/tracks/32h59T8q2Son...
#
#              type                                   uri  valence
# 0  audio_features  spotify:track:60a0Rd6pjrkxjPbaKzXjfq    0.400
# 1  audio_features  spotify:track:6ZOBP3NvffbU4SZcrnt1k6    0.543
# 2  audio_features  spotify:track:3yfqSUWxFvZELEM4PmlwIR    0.760
# 3  audio_features  spotify:track:0I3q5fE6wg7LIfHGngUTnV    0.615
# 4  audio_features  spotify:track:32h59T8q2SonUPJ006lyXt    0.701

# %%
# Join both datasets
df00 = pd.merge(df_2000, info00, on='id', how='inner')
df00.head()
# Out:
#                  track              artist  popularity  \
# 0           In the End         Linkin Park          83
# 1           Kryptonite        3 Doors Down          77
# 2  The Real Slim Shady              Eminem          80
# 3          Ms. Jackson             OutKast          77
# 4       This Christmas  Christina Aguilera          77
#
#                        id  acousticness  \
# 0  60a0Rd6pjrkxjPbaKzXjfq       0.00958
# 1  6ZOBP3NvffbU4SZcrnt1k6       0.00664
# 2  3yfqSUWxFvZELEM4PmlwIR       0.03020
# 3  0I3q5fE6wg7LIfHGngUTnV       0.14200
# 4  32h59T8q2SonUPJ006lyXt       0.06870
#
#                                         analysis_url  danceability  \
# 0  https://api.spotify.com/v1/audio-analysis/60a0...         0.556
# 1  https://api.spotify.com/v1/audio-analysis/6ZOB...         0.545
# 2  https://api.spotify.com/v1/audio-analysis/3yfq...         0.949
# 3  https://api.spotify.com/v1/audio-analysis/0I3q...         0.843
# 4  https://api.spotify.com/v1/audio-analysis/32h5...         0.575
#
#    duration_ms  energy  instrumentalness  ...  liveness  loudness  mode  \
# 0       216880   0.864          0.000000  ...    0.2090    -5.870     0
# 1       233933   0.865          0.000011  ...    0.1680    -5.708     0
# 2       284200   0.661          0.000000  ...    0.0454    -4.244     0
# 3       270507   0.805          0.000000  ...    0.0771    -5.946     0
# 4       241507   0.744          0.000000  ...    0.0723    -5.466     1
#
#    speechiness    tempo  time_signature  \
# 0       0.0584  105.143               4
# 1       0.0286   99.010               4
# 2       0.0572  104.504               4
# 3       0.2690   94.946               4
# 4       0.0603  183.790               4
#
#                                           track_href            type  \
# 0  https://api.spotify.com/v1/tracks/60a0Rd6pjrkx...  audio_features
# 1  https://api.spotify.com/v1/tracks/6ZOBP3NvffbU...  audio_features
# 2  https://api.spotify.com/v1/tracks/3yfqSUWxFvZE...  audio_features
# 3  https://api.spotify.com/v1/tracks/0I3q5fE6wg7L...  audio_features
# 4  https://api.spotify.com/v1/tracks/32h59T8q2Son...  audio_features
#
#                                     uri valence
# 0  spotify:track:60a0Rd6pjrkxjPbaKzXjfq   0.400
# 1  spotify:track:6ZOBP3NvffbU4SZcrnt1k6   0.543
# 2  spotify:track:3yfqSUWxFvZELEM4PmlwIR   0.760
# 3  spotify:track:0I3q5fE6wg7LIfHGngUTnV   0.615
# 4  spotify:track:32h59T8q2SonUPJ006lyXt   0.701
#
# [5 rows x 21 columns]

# %%
# Drop irrelevant columns
df2000 = df00.drop(['analysis_url', 'track_href', 'type', 'uri'], axis=1)
df2000.head()
# Out:
#                  track              artist  popularity  \
# 0           In the End         Linkin Park          83
# 1           Kryptonite        3 Doors Down          77
# 2  The Real Slim Shady              Eminem          80
# 3          Ms. Jackson             OutKast          77
# 4       This Christmas  Christina Aguilera          77
#
#                        id  acousticness  danceability  duration_ms  energy  \
# 0  60a0Rd6pjrkxjPbaKzXjfq       0.00958         0.556       216880   0.864
# 1  6ZOBP3NvffbU4SZcrnt1k6       0.00664         0.545       233933   0.865
# 2  3yfqSUWxFvZELEM4PmlwIR       0.03020         0.949       284200   0.661
# 3  0I3q5fE6wg7LIfHGngUTnV       0.14200         0.843       270507   0.805
# 4  32h59T8q2SonUPJ006lyXt       0.06870         0.575       241507   0.744
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.000000    3    0.2090    -5.870     0       0.0584  105.143
# 1          0.000011   11    0.1680    -5.708     0       0.0286   99.010
# 2          0.000000    5    0.0454    -4.244     0       0.0572  104.504
# 3          0.000000    4    0.0771    -5.946     0       0.2690   94.946
# 4          0.000000    1    0.0723    -5.466     1       0.0603  183.790
#
#    time_signature  valence
# 0               4    0.400
# 1               4    0.543
# 2               4    0.760
# 3               4    0.615
# 4               4    0.701

# %%
# Check for duplicates
df2000.nunique()
# Out:
# track                984
# artist               464
# popularity            43
# id                  1000
# acousticness         815
# danceability         516
# duration_ms          960
# energy               582
# instrumentalness     581
# key                   12
# liveness             552
# loudness             940
# mode                   2
# speechiness          542
# tempo                986
# time_signature         4
# valence              630
# dtype: int64

# %%
# Send to CSV
df2000.to_csv("spotify2000.csv")

# %% [markdown]
# ### 2005

# %%
# Lists to store data
track_name = []
artist = []
track_id = []
popularity = []

# %%
# Loop through general track info
for i in range(0, 1000, 50):
    year_2005 = sp.search(q='year:2005', type='track', limit=50, offset=i)
    for i, a in enumerate(year_2005['tracks']['items']):
        
        track_name.append(a['name'])
        artist.append(a['artists'][0]['name'])
        popularity.append(a['popularity'])
        track_id.append(a['id'])

len(track_name)
# Out:
# 1000

# %%
df_2005 = pd.DataFrame({'track':track_name, 'artist':artist, 'popularity':popularity, 'id':track_id})
df_2005.head()
# Out:
#                                       track               artist  popularity  \
# 0                         Hey There Delilah      Plain White T's          80
# 1                I Write Sins Not Tragedies  Panic! At The Disco          74
# 2                    Sugar, We're Goin Down         Fall Out Boy          77
# 3  Lose Yourself - From "8 Mile" Soundtrack               Eminem          77
# 4                            Feel Good Inc.             Gorillaz          80
#
#                        id
# 0  4RCWB3V8V0dignt99LZ8vH
# 1  4bPQs0PHn4xbipzdPfn6du
# 2  2TfSHkHiFO4gRztVIkggkE
# 3  5Z01UMMf7V1o0MzF86s6WJ
# 4  0d28khcov6AiegSCpG5TuT

# %%
# Get track feautured information

# Lists to match data to df_2005
new05 = []
limitsize = 100
none05 = 0

# %%
# Get track feautured information
for i in range(0, len(df_2005['id']), limitsize):
    feat_05 = df_2005['id'][i:i+limitsize]
    res_05 = sp.audio_features(feat_05)
    for i, a in enumerate(res_05):
        if a == None:
            none05 = none05 + 1
        else:
            new05.append(a)
            
len(new05)
# Out:
# 1000

# %%
info05 = pd.DataFrame.from_dict(new05, orient='columns')
info05.head()
# Out:
#    acousticness                                       analysis_url  \
# 0       0.87200  https://api.spotify.com/v1/audio-analysis/4RCW...
# 1       0.09380  https://api.spotify.com/v1/audio-analysis/4bPQ...
# 2       0.00579  https://api.spotify.com/v1/audio-analysis/2TfS...
# 3       0.00868  https://api.spotify.com/v1/audio-analysis/5Z01...
# 4       0.00836  https://api.spotify.com/v1/audio-analysis/0d28...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.657       232533   0.291  4RCWB3V8V0dignt99LZ8vH
# 1         0.567       187613   0.795  4bPQs0PHn4xbipzdPfn6du
# 2         0.494       229093   0.841  2TfSHkHiFO4gRztVIkggkE
# 3         0.692       326467   0.744  5Z01UMMf7V1o0MzF86s6WJ
# 4         0.818       222640   0.705  0d28khcov6AiegSCpG5TuT
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.000000    2     0.114   -10.572     1       0.0293  103.973
# 1          0.000000    9     0.114    -4.985     0       0.1340  170.060
# 2          0.000000    7     0.122    -4.784     1       0.0838  162.013
# 3          0.000423    2     0.359    -4.565     1       0.2570  171.374
# 4          0.002330    6     0.613    -6.679     1       0.1770  138.559
#
#    time_signature                                         track_href  \
# 0               4  https://api.spotify.com/v1/tracks/4RCWB3V8V0di...
# 1               4  https://api.spotify.com/v1/tracks/4bPQs0PHn4xb...
# 2               4  https://api.spotify.com/v1/tracks/2TfSHkHiFO4g...
# 3               4  https://api.spotify.com/v1/tracks/5Z01UMMf7V1o...
# 4               4  https://api.spotify.com/v1/tracks/0d28khcov6Ai...
#
#              type                                   uri  valence
# 0  audio_features  spotify:track:4RCWB3V8V0dignt99LZ8vH   0.2980
# 1  audio_features  spotify:track:4bPQs0PHn4xbipzdPfn6du   0.6350
# 2  audio_features  spotify:track:2TfSHkHiFO4gRztVIkggkE   0.5670
# 3  audio_features  spotify:track:5Z01UMMf7V1o0MzF86s6WJ   0.0612
# 4  audio_features  spotify:track:0d28khcov6AiegSCpG5TuT   0.7720

# %%
# Join both datasets
df05 = pd.merge(df_2005, info05, on='id', how='inner')
df05.head()
# Out:
#                                       track               artist  popularity  \
# 0                         Hey There Delilah      Plain White T's          80
# 1                I Write Sins Not Tragedies  Panic! At The Disco          74
# 2                    Sugar, We're Goin Down         Fall Out Boy          77
# 3  Lose Yourself - From "8 Mile" Soundtrack               Eminem          77
# 4                            Feel Good Inc.             Gorillaz          80
#
#                        id  acousticness  \
# 0  4RCWB3V8V0dignt99LZ8vH       0.87200
# 1  4bPQs0PHn4xbipzdPfn6du       0.09380
# 2  2TfSHkHiFO4gRztVIkggkE       0.00579
# 3  5Z01UMMf7V1o0MzF86s6WJ       0.00868
# 4  0d28khcov6AiegSCpG5TuT       0.00836
#
#                                         analysis_url  danceability  \
# 0  https://api.spotify.com/v1/audio-analysis/4RCW...         0.657
# 1  https://api.spotify.com/v1/audio-analysis/4bPQ...         0.567
# 2  https://api.spotify.com/v1/audio-analysis/2TfS...         0.494
# 3  https://api.spotify.com/v1/audio-analysis/5Z01...         0.692
# 4  https://api.spotify.com/v1/audio-analysis/0d28...         0.818
#
#    duration_ms  energy  instrumentalness  ...  liveness  loudness  mode  \
# 0       232533   0.291          0.000000  ...     0.114   -10.572     1
# 1       187613   0.795          0.000000  ...     0.114    -4.985     0
# 2       229093   0.841          0.000000  ...     0.122    -4.784     1
# 3       326467   0.744          0.000423  ...     0.359    -4.565     1
# 4       222640   0.705          0.002330  ...     0.613    -6.679     1
#
#    speechiness    tempo  time_signature  \
# 0       0.0293  103.973               4
# 1       0.1340  170.060               4
# 2       0.0838  162.013               4
# 3       0.2570  171.374               4
# 4       0.1770  138.559               4
#
#                                           track_href            type  \
# 0  https://api.spotify.com/v1/tracks/4RCWB3V8V0di...  audio_features
# 1  https://api.spotify.com/v1/tracks/4bPQs0PHn4xb...  audio_features
# 2  https://api.spotify.com/v1/tracks/2TfSHkHiFO4g...  audio_features
# 3  https://api.spotify.com/v1/tracks/5Z01UMMf7V1o...  audio_features
# 4  https://api.spotify.com/v1/tracks/0d28khcov6Ai...  audio_features
#
#                                     uri valence
# 0  spotify:track:4RCWB3V8V0dignt99LZ8vH  0.2980
# 1  spotify:track:4bPQs0PHn4xbipzdPfn6du  0.6350
# 2  spotify:track:2TfSHkHiFO4gRztVIkggkE  0.5670
# 3  spotify:track:5Z01UMMf7V1o0MzF86s6WJ  0.0612
# 4  spotify:track:0d28khcov6AiegSCpG5TuT  0.7720
#
# [5 rows x 21 columns]

# %%
# Drop irrelevant columns
df2005 = df05.drop(['analysis_url', 'track_href', 'type', 'uri'], axis=1)
df2005.head()
# Out:
#                                       track               artist  popularity  \
# 0                         Hey There Delilah      Plain White T's          80
# 1                I Write Sins Not Tragedies  Panic! At The Disco          74
# 2                    Sugar, We're Goin Down         Fall Out Boy          77
# 3  Lose Yourself - From "8 Mile" Soundtrack               Eminem          77
# 4                            Feel Good Inc.             Gorillaz          80
#
#                        id  acousticness  danceability  duration_ms  energy  \
# 0  4RCWB3V8V0dignt99LZ8vH       0.87200         0.657       232533   0.291
# 1  4bPQs0PHn4xbipzdPfn6du       0.09380         0.567       187613   0.795
# 2  2TfSHkHiFO4gRztVIkggkE       0.00579         0.494       229093   0.841
# 3  5Z01UMMf7V1o0MzF86s6WJ       0.00868         0.692       326467   0.744
# 4  0d28khcov6AiegSCpG5TuT       0.00836         0.818       222640   0.705
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.000000    2     0.114   -10.572     1       0.0293  103.973
# 1          0.000000    9     0.114    -4.985     0       0.1340  170.060
# 2          0.000000    7     0.122    -4.784     1       0.0838  162.013
# 3          0.000423    2     0.359    -4.565     1       0.2570  171.374
# 4          0.002330    6     0.613    -6.679     1       0.1770  138.559
#
#    time_signature  valence
# 0               4   0.2980
# 1               4   0.6350
# 2               4   0.5670
# 3               4   0.0612
# 4               4   0.7720

# %%
# Check for duplicates
df2005.nunique()
# Out:
# track                976
# artist               474
# popularity            39
# id                  1000
# acousticness         811
# danceability         528
# duration_ms          942
# energy               567
# instrumentalness     524
# key                   12
# liveness             543
# loudness             943
# mode                   2
# speechiness          571
# tempo                983
# time_signature         4
# valence              596
# dtype: int64

# %%
# Send to CSV
df2005.to_csv("spotify2005.csv")

# %% [markdown]
# ### 2010

# %%
# Lists to store data
track_name = []
artist = []
track_id = []
popularity = []

# %%
# Loop through general track info
for i in range(0, 1000, 50):
    year_2010 = sp.search(q='year:2010', type='track', limit=50, offset=i)
    for i, a in enumerate(year_2010['tracks']['items']):
        
        track_name.append(a['name'])
        artist.append(a['artists'][0]['name'])
        popularity.append(a['popularity'])
        track_id.append(a['id'])

len(track_name)
# Out:
# 1000

# %%
df_2010 = pd.DataFrame({'track':track_name, 'artist':artist, 'popularity':popularity, 'id':track_id})
df_2010.head()
# Out:
#                                    track             artist  popularity  \
# 0  Happy Xmas (War Is Over) - Remastered        John Lennon          87
# 1                   Just the Way You Are         Bruno Mars          80
# 2                       Hey, Soul Sister              Train          82
# 3    No Hands (feat. Roscoe Dash & Wale)  Waka Flocka Flame          74
# 4                   Love The Way You Lie             Eminem          82
#
#                        id
# 0  3zJw3rugfpVrmBeDDnUYzy
# 1  7BqBn9nzAq8spo5e7cZ0dJ
# 2  4HlFJV71xXKIGcU3kRyttv
# 3  03tqyYWC9Um2ZqU0ZN849H
# 4  15JINEqzVMv3SvJTAXAKED

# %%
# Get track feautured information

# Lists to match data to df_2010
new10 = []
limitsize = 100
none10 = 0

# %%
# Get track feautured information
for i in range(0, len(df_2010['id']), limitsize):
    feat_10 = df_2010['id'][i:i+limitsize]
    res_10 = sp.audio_features(feat_10)
    for i, a in enumerate(res_10):
        if a == None:
            none10 = none10 + 1
        else:
            new10.append(a)
            
len(new10)
# Out:
# 1000

# %%
info10 = pd.DataFrame.from_dict(new10, orient='columns')
info10.head()
# Out:
#    acousticness                                       analysis_url  \
# 0       0.31900  https://api.spotify.com/v1/audio-analysis/3zJw...
# 1       0.01510  https://api.spotify.com/v1/audio-analysis/7BqB...
# 2       0.18500  https://api.spotify.com/v1/audio-analysis/4HlF...
# 3       0.00544  https://api.spotify.com/v1/audio-analysis/03tq...
# 4       0.24100  https://api.spotify.com/v1/audio-analysis/15JI...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.328       213880   0.607  3zJw3rugfpVrmBeDDnUYzy
# 1         0.637       220733   0.843  7BqBn9nzAq8spo5e7cZ0dJ
# 2         0.673       216773   0.886  4HlFJV71xXKIGcU3kRyttv
# 3         0.760       263773   0.595  03tqyYWC9Um2ZqU0ZN849H
# 4         0.749       263373   0.925  15JINEqzVMv3SvJTAXAKED
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0               0.0    2    0.7650   -11.076     1       0.0315  146.539
# 1               0.0    5    0.0876    -5.413     1       0.0432  109.012
# 2               0.0    1    0.0826    -4.440     0       0.0431   97.012
# 3               0.0    1    0.2410    -6.366     1       0.0391  131.497
# 4               0.0   10    0.5200    -5.034     1       0.2270   86.989
#
#    time_signature                                         track_href  \
# 0               3  https://api.spotify.com/v1/tracks/3zJw3rugfpVr...
# 1               4  https://api.spotify.com/v1/tracks/7BqBn9nzAq8s...
# 2               4  https://api.spotify.com/v1/tracks/4HlFJV71xXKI...
# 3               4  https://api.spotify.com/v1/tracks/03tqyYWC9Um2...
# 4               4  https://api.spotify.com/v1/tracks/15JINEqzVMv3...
#
#              type                                   uri  valence
# 0  audio_features  spotify:track:3zJw3rugfpVrmBeDDnUYzy    0.395
# 1  audio_features  spotify:track:7BqBn9nzAq8spo5e7cZ0dJ    0.434
# 2  audio_features  spotify:track:4HlFJV71xXKIGcU3kRyttv    0.795
# 3  audio_features  spotify:track:03tqyYWC9Um2ZqU0ZN849H    0.361
# 4  audio_features  spotify:track:15JINEqzVMv3SvJTAXAKED    0.641

# %%
# Join both datasets
df10 = pd.merge(df_2010, info10, on='id', how='inner')
df10.head()
# Out:
#                                    track             artist  popularity  \
# 0  Happy Xmas (War Is Over) - Remastered        John Lennon          87
# 1                   Just the Way You Are         Bruno Mars          80
# 2                       Hey, Soul Sister              Train          82
# 3    No Hands (feat. Roscoe Dash & Wale)  Waka Flocka Flame          74
# 4                   Love The Way You Lie             Eminem          82
#
#                        id  acousticness  \
# 0  3zJw3rugfpVrmBeDDnUYzy       0.31900
# 1  7BqBn9nzAq8spo5e7cZ0dJ       0.01510
# 2  4HlFJV71xXKIGcU3kRyttv       0.18500
# 3  03tqyYWC9Um2ZqU0ZN849H       0.00544
# 4  15JINEqzVMv3SvJTAXAKED       0.24100
#
#                                         analysis_url  danceability  \
# 0  https://api.spotify.com/v1/audio-analysis/3zJw...         0.328
# 1  https://api.spotify.com/v1/audio-analysis/7BqB...         0.637
# 2  https://api.spotify.com/v1/audio-analysis/4HlF...         0.673
# 3  https://api.spotify.com/v1/audio-analysis/03tq...         0.760
# 4  https://api.spotify.com/v1/audio-analysis/15JI...         0.749
#
#    duration_ms  energy  instrumentalness  ...  liveness  loudness  mode  \
# 0       213880   0.607               0.0  ...    0.7650   -11.076     1
# 1       220733   0.843               0.0  ...    0.0876    -5.413     1
# 2       216773   0.886               0.0  ...    0.0826    -4.440     0
# 3       263773   0.595               0.0  ...    0.2410    -6.366     1
# 4       263373   0.925               0.0  ...    0.5200    -5.034     1
#
#    speechiness    tempo  time_signature  \
# 0       0.0315  146.539               3
# 1       0.0432  109.012               4
# 2       0.0431   97.012               4
# 3       0.0391  131.497               4
# 4       0.2270   86.989               4
#
#                                           track_href            type  \
# 0  https://api.spotify.com/v1/tracks/3zJw3rugfpVr...  audio_features
# 1  https://api.spotify.com/v1/tracks/7BqBn9nzAq8s...  audio_features
# 2  https://api.spotify.com/v1/tracks/4HlFJV71xXKI...  audio_features
# 3  https://api.spotify.com/v1/tracks/03tqyYWC9Um2...  audio_features
# 4  https://api.spotify.com/v1/tracks/15JINEqzVMv3...  audio_features
#
#                                     uri valence
# 0  spotify:track:3zJw3rugfpVrmBeDDnUYzy   0.395
# 1  spotify:track:7BqBn9nzAq8spo5e7cZ0dJ   0.434
# 2  spotify:track:4HlFJV71xXKIGcU3kRyttv   0.795
# 3  spotify:track:03tqyYWC9Um2ZqU0ZN849H   0.361
# 4  spotify:track:15JINEqzVMv3SvJTAXAKED   0.641
#
# [5 rows x 21 columns]

# %%
# Drop irrelevant columns
df2010 = df10.drop(['analysis_url', 'track_href', 'type', 'uri'], axis=1)
df2010.head()
# Out:
#                                    track             artist  popularity  \
# 0  Happy Xmas (War Is Over) - Remastered        John Lennon          87
# 1                   Just the Way You Are         Bruno Mars          80
# 2                       Hey, Soul Sister              Train          82
# 3    No Hands (feat. Roscoe Dash & Wale)  Waka Flocka Flame          74
# 4                   Love The Way You Lie             Eminem          82
#
#                        id  acousticness  danceability  duration_ms  energy  \
# 0  3zJw3rugfpVrmBeDDnUYzy       0.31900         0.328       213880   0.607
# 1  7BqBn9nzAq8spo5e7cZ0dJ       0.01510         0.637       220733   0.843
# 2  4HlFJV71xXKIGcU3kRyttv       0.18500         0.673       216773   0.886
# 3  03tqyYWC9Um2ZqU0ZN849H       0.00544         0.760       263773   0.595
# 4  15JINEqzVMv3SvJTAXAKED       0.24100         0.749       263373   0.925
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0               0.0    2    0.7650   -11.076     1       0.0315  146.539
# 1               0.0    5    0.0876    -5.413     1       0.0432  109.012
# 2               0.0    1    0.0826    -4.440     0       0.0431   97.012
# 3               0.0    1    0.2410    -6.366     1       0.0391  131.497
# 4               0.0   10    0.5200    -5.034     1       0.2270   86.989
#
#    time_signature  valence
# 0               3    0.395
# 1               4    0.434
# 2               4    0.795
# 3               4    0.361
# 4               4    0.641

# %%
# Check for duplicates
df2010.nunique()
# Out:
# track                967
# artist               442
# popularity            37
# id                  1000
# acousticness         782
# danceability         511
# duration_ms          945
# energy               525
# instrumentalness     504
# key                   12
# liveness             488
# loudness             918
# mode                   2
# speechiness          547
# tempo                957
# time_signature         4
# valence              610
# dtype: int64

# %%
# Send to CSV
df2010.to_csv("spotify2010.csv")

# %% [markdown]
# ### 2015

# %%
# Lists to store data
track_name = []
artist = []
track_id = []
popularity = []

# %%
# Loop through general track info
for i in range(0, 1000, 50):
    year_2015 = sp.search(q='year:2015', type='track', limit=50, offset=i)
    for i, a in enumerate(year_2015['tracks']['items']):
        
        track_name.append(a['name'])
        artist.append(a['artists'][0]['name'])
        popularity.append(a['popularity'])
        track_id.append(a['id'])

len(track_name)
# Out:
# 1000

# %%
df_2015 = pd.DataFrame({'track':track_name, 'artist':artist, 'popularity':popularity, 'id':track_id})
df_2015.head()
# Out:
#                         track           artist  popularity  \
# 0  The Less I Know The Better      Tame Impala          85
# 1                       Don't    Bryson Tiller          80
# 2                    Exchange    Bryson Tiller          79
# 3                   The Hills       The Weeknd          84
# 4           Tennessee Whiskey  Chris Stapleton          77
#
#                        id
# 0  6K4t31amVTZDgR3sKmwUJJ
# 1  3pXF1nA74528Edde4of9CC
# 2  43PuMrRfbyyuz4QpZ3oAwN
# 3  7fBv7CLKzipRk6EC6TWHOB
# 4  3fqwjXwUGN6vbzIwvyFMhx

# %%
# Get track feautured information

# Lists to match data to df_2015
new15 = []
limitsize = 100
none15 = 0

# %%
# Get track feautured information
for i in range(0, len(df_2015['id']), limitsize):
    feat_15 = df_2015['id'][i:i+limitsize]
    res_15 = sp.audio_features(feat_15)
    for i, a in enumerate(res_15):
        if a == None:
            none15 = none15 + 1
        else:
            new15.append(a)
            
len(new15)
# Out:
# 1000

# %%
info15 = pd.DataFrame.from_dict(new15, orient='columns')
info15.head()
# Out:
#    acousticness                                       analysis_url  \
# 0        0.0115  https://api.spotify.com/v1/audio-analysis/6K4t...
# 1        0.2220  https://api.spotify.com/v1/audio-analysis/3pXF...
# 2        0.1080  https://api.spotify.com/v1/audio-analysis/43Pu...
# 3        0.0671  https://api.spotify.com/v1/audio-analysis/7fBv...
# 4        0.2050  https://api.spotify.com/v1/audio-analysis/3fqw...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.640       216320   0.740  6K4t31amVTZDgR3sKmwUJJ
# 1         0.765       198293   0.356  3pXF1nA74528Edde4of9CC
# 2         0.530       194613   0.433  43PuMrRfbyyuz4QpZ3oAwN
# 3         0.580       242253   0.565  7fBv7CLKzipRk6EC6TWHOB
# 4         0.392       293293   0.370  3fqwjXwUGN6vbzIwvyFMhx
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0           0.00678    4    0.1670    -4.083     1       0.0284  116.879
# 1           0.00000   11    0.0963    -5.556     0       0.1960   97.001
# 2           0.00000    6    0.1350   -10.598     1       0.1850  160.140
# 3           0.00000    0    0.1350    -7.065     0       0.0488  112.986
# 4           0.00960    9    0.0821   -10.888     1       0.0298   48.718
#
#    time_signature                                         track_href  \
# 0               4  https://api.spotify.com/v1/tracks/6K4t31amVTZD...
# 1               4  https://api.spotify.com/v1/tracks/3pXF1nA74528...
# 2               4  https://api.spotify.com/v1/tracks/43PuMrRfbyyu...
# 3               4  https://api.spotify.com/v1/tracks/7fBv7CLKzipR...
# 4               4  https://api.spotify.com/v1/tracks/3fqwjXwUGN6v...
#
#              type                                   uri  valence
# 0  audio_features  spotify:track:6K4t31amVTZDgR3sKmwUJJ    0.785
# 1  audio_features  spotify:track:3pXF1nA74528Edde4of9CC    0.190
# 2  audio_features  spotify:track:43PuMrRfbyyuz4QpZ3oAwN    0.274
# 3  audio_features  spotify:track:7fBv7CLKzipRk6EC6TWHOB    0.138
# 4  audio_features  spotify:track:3fqwjXwUGN6vbzIwvyFMhx    0.512

# %%
# Join both datasets
df15 = pd.merge(df_2015, info15, on='id', how='inner')
df15.head()
# Out:
#                         track           artist  popularity  \
# 0  The Less I Know The Better      Tame Impala          85
# 1                       Don't    Bryson Tiller          80
# 2                    Exchange    Bryson Tiller          79
# 3                   The Hills       The Weeknd          84
# 4           Tennessee Whiskey  Chris Stapleton          77
#
#                        id  acousticness  \
# 0  6K4t31amVTZDgR3sKmwUJJ        0.0115
# 1  3pXF1nA74528Edde4of9CC        0.2220
# 2  43PuMrRfbyyuz4QpZ3oAwN        0.1080
# 3  7fBv7CLKzipRk6EC6TWHOB        0.0671
# 4  3fqwjXwUGN6vbzIwvyFMhx        0.2050
#
#                                         analysis_url  danceability  \
# 0  https://api.spotify.com/v1/audio-analysis/6K4t...         0.640
# 1  https://api.spotify.com/v1/audio-analysis/3pXF...         0.765
# 2  https://api.spotify.com/v1/audio-analysis/43Pu...         0.530
# 3  https://api.spotify.com/v1/audio-analysis/7fBv...         0.580
# 4  https://api.spotify.com/v1/audio-analysis/3fqw...         0.392
#
#    duration_ms  energy  instrumentalness  ...  liveness  loudness  mode  \
# 0       216320   0.740           0.00678  ...    0.1670    -4.083     1
# 1       198293   0.356           0.00000  ...    0.0963    -5.556     0
# 2       194613   0.433           0.00000  ...    0.1350   -10.598     1
# 3       242253   0.565           0.00000  ...    0.1350    -7.065     0
# 4       293293   0.370           0.00960  ...    0.0821   -10.888     1
#
#    speechiness    tempo  time_signature  \
# 0       0.0284  116.879               4
# 1       0.1960   97.001               4
# 2       0.1850  160.140               4
# 3       0.0488  112.986               4
# 4       0.0298   48.718               4
#
#                                           track_href            type  \
# 0  https://api.spotify.com/v1/tracks/6K4t31amVTZD...  audio_features
# 1  https://api.spotify.com/v1/tracks/3pXF1nA74528...  audio_features
# 2  https://api.spotify.com/v1/tracks/43PuMrRfbyyu...  audio_features
# 3  https://api.spotify.com/v1/tracks/7fBv7CLKzipR...  audio_features
# 4  https://api.spotify.com/v1/tracks/3fqwjXwUGN6v...  audio_features
#
#                                     uri valence
# 0  spotify:track:6K4t31amVTZDgR3sKmwUJJ   0.785
# 1  spotify:track:3pXF1nA74528Edde4of9CC   0.190
# 2  spotify:track:43PuMrRfbyyuz4QpZ3oAwN   0.274
# 3  spotify:track:7fBv7CLKzipRk6EC6TWHOB   0.138
# 4  spotify:track:3fqwjXwUGN6vbzIwvyFMhx   0.512
#
# [5 rows x 21 columns]

# %%
# Drop irrelevant columns
df2015 = df15.drop(['analysis_url', 'track_href', 'type', 'uri'], axis=1)
df2015.head()
# Out:
#                         track           artist  popularity  \
# 0  The Less I Know The Better      Tame Impala          85
# 1                       Don't    Bryson Tiller          80
# 2                    Exchange    Bryson Tiller          79
# 3                   The Hills       The Weeknd          84
# 4           Tennessee Whiskey  Chris Stapleton          77
#
#                        id  acousticness  danceability  duration_ms  energy  \
# 0  6K4t31amVTZDgR3sKmwUJJ        0.0115         0.640       216320   0.740
# 1  3pXF1nA74528Edde4of9CC        0.2220         0.765       198293   0.356
# 2  43PuMrRfbyyuz4QpZ3oAwN        0.1080         0.530       194613   0.433
# 3  7fBv7CLKzipRk6EC6TWHOB        0.0671         0.580       242253   0.565
# 4  3fqwjXwUGN6vbzIwvyFMhx        0.2050         0.392       293293   0.370
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0           0.00678    4    0.1670    -4.083     1       0.0284  116.879
# 1           0.00000   11    0.0963    -5.556     0       0.1960   97.001
# 2           0.00000    6    0.1350   -10.598     1       0.1850  160.140
# 3           0.00000    0    0.1350    -7.065     0       0.0488  112.986
# 4           0.00960    9    0.0821   -10.888     1       0.0298   48.718
#
#    time_signature  valence
# 0               4    0.785
# 1               4    0.190
# 2               4    0.274
# 3               4    0.138
# 4               4    0.512

# %%
# Check for duplicates
df2015.nunique()
# Out:
# track                972
# artist               435
# popularity            32
# id                  1000
# acousticness         771
# danceability         491
# duration_ms          969
# energy               555
# instrumentalness     454
# key                   12
# liveness             491
# loudness             939
# mode                   2
# speechiness          615
# tempo                974
# time_signature         5
# valence              578
# dtype: int64

# %%
# Send to CSV
df2015.to_csv("spotify2015.csv")

# %% [markdown]
# ### 2019

# %%
# Lists to store data
track_name = []
artist = []
track_id = []
popularity = []

# %%
# Loop through general track info
for i in range(0, 1000, 50):
    year_2019 = sp.search(q='year:2019', type='track', limit=50, offset=i)
    for i, a in enumerate(year_2019['tracks']['items']):
        
        track_name.append(a['name'])
        artist.append(a['artists'][0]['name'])
        popularity.append(a['popularity'])
        track_id.append(a['id'])

len(track_name)
# Out:
# 1000

# %%
df_2019 = pd.DataFrame({'track':track_name, 'artist':artist, 'popularity':popularity, 'id':track_id})
df_2019.head()
# Out:
#                                       track          artist  popularity  \
# 0                                   The Box     Roddy Ricch          95
# 1                                   ROXANNE  Arizona Zervas          99
# 2                                   Circles     Post Malone          98
# 3  Bandit (with YoungBoy Never Broke Again)      Juice WRLD          93
# 4                                       BOP          DaBaby          93
#
#                        id
# 0  0nbXyq5TXYPCO7pr3N8S4I
# 1  696DnlkuDOXcMAnKlTgXXK
# 2  21jGcNKet2qwijlDFuPiPb
# 3  6Gg1gjgKi2AK4e0qzsR7sd
# 4  6Ozh9Ok6h4Oi1wUSLtBseN

# %%
# Get track feautured information

# Lists to match data to df_2019
new19 = []
limitsize = 100
none19 = 0

# %%
# Get track feautured information
for i in range(0, len(df_2019['id']), limitsize):
    feat_19 = df_2019['id'][i:i+limitsize]
    res_19 = sp.audio_features(feat_19)
    for i, a in enumerate(res_19):
        if a == None:
            none19 = none19 + 1
        else:
            new19.append(a)
            
len(new19)
# Out:
# 1000

# %%
info19 = pd.DataFrame.from_dict(new19, orient='columns')
info19.head()
# Out:
#    acousticness                                       analysis_url  \
# 0        0.1040  https://api.spotify.com/v1/audio-analysis/0nbX...
# 1        0.0522  https://api.spotify.com/v1/audio-analysis/696D...
# 2        0.1920  https://api.spotify.com/v1/audio-analysis/21jG...
# 3        0.0687  https://api.spotify.com/v1/audio-analysis/6Gg1...
# 4        0.1890  https://api.spotify.com/v1/audio-analysis/6Ozh...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.896       196653   0.586  0nbXyq5TXYPCO7pr3N8S4I
# 1         0.621       163636   0.601  696DnlkuDOXcMAnKlTgXXK
# 2         0.695       215280   0.762  21jGcNKet2qwijlDFuPiPb
# 3         0.474       189323   0.631  6Gg1gjgKi2AK4e0qzsR7sd
# 4         0.769       159715   0.787  6Ozh9Ok6h4Oi1wUSLtBseN
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0           0.00000   10    0.7900    -6.687     0       0.0559  116.971
# 1           0.00000    6    0.4600    -5.616     0       0.1480  116.735
# 2           0.00244    0    0.0863    -3.497     1       0.0395  120.042
# 3           0.00000    5    0.1320    -5.884     0       0.3430  180.051
# 4           0.00000   11    0.1290    -3.909     1       0.3670  126.770
#
#    time_signature                                         track_href  \
# 0               4  https://api.spotify.com/v1/tracks/0nbXyq5TXYPC...
# 1               5  https://api.spotify.com/v1/tracks/696DnlkuDOXc...
# 2               4  https://api.spotify.com/v1/tracks/21jGcNKet2qw...
# 3               4  https://api.spotify.com/v1/tracks/6Gg1gjgKi2AK...
# 4               4  https://api.spotify.com/v1/tracks/6Ozh9Ok6h4Oi...
#
#              type                                   uri  valence
# 0  audio_features  spotify:track:0nbXyq5TXYPCO7pr3N8S4I    0.642
# 1  audio_features  spotify:track:696DnlkuDOXcMAnKlTgXXK    0.457
# 2  audio_features  spotify:track:21jGcNKet2qwijlDFuPiPb    0.553
# 3  audio_features  spotify:track:6Gg1gjgKi2AK4e0qzsR7sd    0.425
# 4  audio_features  spotify:track:6Ozh9Ok6h4Oi1wUSLtBseN    0.836

# %%
# Join both datasets
df19 = pd.merge(df_2019, info19, on='id', how='inner')
df19.head()
# Out:
#                                       track          artist  popularity  \
# 0                                   The Box     Roddy Ricch          95
# 1                                   ROXANNE  Arizona Zervas          99
# 2                                   Circles     Post Malone          98
# 3  Bandit (with YoungBoy Never Broke Again)      Juice WRLD          93
# 4                                       BOP          DaBaby          93
#
#                        id  acousticness  \
# 0  0nbXyq5TXYPCO7pr3N8S4I        0.1040
# 1  696DnlkuDOXcMAnKlTgXXK        0.0522
# 2  21jGcNKet2qwijlDFuPiPb        0.1920
# 3  6Gg1gjgKi2AK4e0qzsR7sd        0.0687
# 4  6Ozh9Ok6h4Oi1wUSLtBseN        0.1890
#
#                                         analysis_url  danceability  \
# 0  https://api.spotify.com/v1/audio-analysis/0nbX...         0.896
# 1  https://api.spotify.com/v1/audio-analysis/696D...         0.621
# 2  https://api.spotify.com/v1/audio-analysis/21jG...         0.695
# 3  https://api.spotify.com/v1/audio-analysis/6Gg1...         0.474
# 4  https://api.spotify.com/v1/audio-analysis/6Ozh...         0.769
#
#    duration_ms  energy  instrumentalness  ...  liveness  loudness  mode  \
# 0       196653   0.586           0.00000  ...    0.7900    -6.687     0
# 1       163636   0.601           0.00000  ...    0.4600    -5.616     0
# 2       215280   0.762           0.00244  ...    0.0863    -3.497     1
# 3       189323   0.631           0.00000  ...    0.1320    -5.884     0
# 4       159715   0.787           0.00000  ...    0.1290    -3.909     1
#
#    speechiness    tempo  time_signature  \
# 0       0.0559  116.971               4
# 1       0.1480  116.735               5
# 2       0.0395  120.042               4
# 3       0.3430  180.051               4
# 4       0.3670  126.770               4
#
#                                           track_href            type  \
# 0  https://api.spotify.com/v1/tracks/0nbXyq5TXYPC...  audio_features
# 1  https://api.spotify.com/v1/tracks/696DnlkuDOXc...  audio_features
# 2  https://api.spotify.com/v1/tracks/21jGcNKet2qw...  audio_features
# 3  https://api.spotify.com/v1/tracks/6Gg1gjgKi2AK...  audio_features
# 4  https://api.spotify.com/v1/tracks/6Ozh9Ok6h4Oi...  audio_features
#
#                                     uri valence
# 0  spotify:track:0nbXyq5TXYPCO7pr3N8S4I   0.642
# 1  spotify:track:696DnlkuDOXcMAnKlTgXXK   0.457
# 2  spotify:track:21jGcNKet2qwijlDFuPiPb   0.553
# 3  spotify:track:6Gg1gjgKi2AK4e0qzsR7sd   0.425
# 4  spotify:track:6Ozh9Ok6h4Oi1wUSLtBseN   0.836
#
# [5 rows x 21 columns]

# %%
# Drop irrelevant columns
df2019 = df19.drop(['analysis_url', 'track_href', 'type', 'uri'], axis=1)
df2019.head()
# Out:
#                                       track          artist  popularity  \
# 0                                   The Box     Roddy Ricch          95
# 1                                   ROXANNE  Arizona Zervas          99
# 2                                   Circles     Post Malone          98
# 3  Bandit (with YoungBoy Never Broke Again)      Juice WRLD          93
# 4                                       BOP          DaBaby          93
#
#                        id  acousticness  danceability  duration_ms  energy  \
# 0  0nbXyq5TXYPCO7pr3N8S4I        0.1040         0.896       196653   0.586
# 1  696DnlkuDOXcMAnKlTgXXK        0.0522         0.621       163636   0.601
# 2  21jGcNKet2qwijlDFuPiPb        0.1920         0.695       215280   0.762
# 3  6Gg1gjgKi2AK4e0qzsR7sd        0.0687         0.474       189323   0.631
# 4  6Ozh9Ok6h4Oi1wUSLtBseN        0.1890         0.769       159715   0.787
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0           0.00000   10    0.7900    -6.687     0       0.0559  116.971
# 1           0.00000    6    0.4600    -5.616     0       0.1480  116.735
# 2           0.00244    0    0.0863    -3.497     1       0.0395  120.042
# 3           0.00000    5    0.1320    -5.884     0       0.3430  180.051
# 4           0.00000   11    0.1290    -3.909     1       0.3670  126.770
#
#    time_signature  valence
# 0               4    0.642
# 1               5    0.457
# 2               4    0.553
# 3               4    0.425
# 4               4    0.836

# %%
# Check for duplicates
df2019.nunique()
# Out:
# track                955
# artist               401
# popularity            36
# id                  1000
# acousticness         700
# danceability         475
# duration_ms          950
# energy               485
# instrumentalness     310
# key                   12
# liveness             464
# loudness             919
# mode                   2
# speechiness          618
# tempo                950
# time_signature         5
# valence              575
# dtype: int64

# %%
# Send to CSV
df2019.to_csv("spotify2019.csv")
