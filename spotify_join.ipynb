# %%
import pandas as pd

# %%
spotify1990= pd.read_csv("spotify1990.csv")
spotify1990.head()
# Out:
#    Unnamed: 0                       track                        artist  \
# 0           0          Carol of the Bells  Mykola Dmytrovych Leontovych
# 1           1              This Christmas                Donny Hathaway
# 2           2               Thunderstruck                         AC/DC
# 3           3  Don't Go Breaking My Heart                    Elton John
# 4           4              Man in the Box               Alice In Chains
#
#    popularity                      id  acousticness  danceability  \
# 0          79  4tHqQMWSqmL6YjXwsqthDI      0.994000         0.418
# 1          78  38xhBO2AKrJnjdjVnhJES6      0.292000         0.634
# 2          81  57bgtoPSgt236HzfBOd8kj      0.000147         0.501
# 3          69  5pKJtX4wBeby9qIfFhyOJj      0.177000         0.742
# 4          71  6gZVQvQZOFpzIy3HblJ20F      0.002290         0.346
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# ...

# %%
spotify1991= pd.read_csv("spotify1991.csv")
spotify1991.head()
# Out:
#    Unnamed: 0                    track                 artist  popularity  \
# 0           0            Enter Sandman              Metallica          74
# 1           1  Smells Like Teen Spirit                Nirvana          74
# 2           2         Under the Bridge  Red Hot Chili Peppers          81
# 3           3          Come As You Are                Nirvana          72
# 4           4     Nothing Else Matters              Metallica          69
#
#                        id  acousticness  danceability  duration_ms  energy  \
# 0  5BIMPccDwShpXq784RJlJp      0.002060         0.579       331573   0.824
# 1  5ghIJDpPoe3CfHMGu71E6T      0.000025         0.502       301920   0.912
# 2  3d9DChrdc6BOeFsbrZ3Is0      0.057600         0.559       264307   0.345
# 3  4P5KoWXOxwuobLmHXLMobV      0.000160         0.500       218920   0.824
# 4  10igKaIKsSB6ZnWxPxPvKO      0.050500         0.558       388733   0.364
#
# ...

# %%
spotify1992= pd.read_csv("spotify1992.csv")
spotify1992.head()
# Out:
#    Unnamed: 0                track                    artist  popularity  \
# 0           0     Jingle Bell Rock               Bobby Helms          87
# 1           1    It Was A Good Day                  Ice Cube          74
# 2           2  Killing In The Name  Rage Against The Machine          78
# 3           3              No Rain               Blind Melon          73
# 4           4          Jump Around             House Of Pain          74
#
#                        id  acousticness  danceability  duration_ms  energy  \
# 0  3hBXvHLlTHvnbwrPbeoyAj        0.6430         0.754       130973   0.424
# 1  2qOm7ukLyHUXWyR4ZWLwxA        0.3300         0.798       260000   0.744
# 2  59WN2psjkt1tyaxjspN8fp        0.0266         0.466       313573   0.833
# 3  6txWz9UapYHVxEd7dDIHXT        0.6190         0.389       217107   0.476
# 4  3TZwjdclvWt7iPJUnMpgcs        0.0113         0.854       214947   0.710
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# ...

# %%
spotify1993= pd.read_csv("spotify1993.csv")
spotify1993.head()
# Out:
#    Unnamed: 0                                track          artist  \
# 0           0                                Creep       Radiohead
# 1           1                            Mr. Jones  Counting Crows
# 2           2  Gin And Juice (feat. Dat Nigga Daz)      Snoop Dogg
# 3           3                     Heart-Shaped Box         Nirvana
# 4           4                           C.R.E.A.M.    Wu-Tang Clan
#
#    popularity                      id  acousticness  danceability  \
# 0          82  6b2oQwSGFkzsMtQruIWm2p        0.0102         0.515
# 1          76  5DiXcVovI0FcY2s0icWWUu        0.1830         0.578
# 2          73  0WKYRFtH6KKbaNWjsxqm70        0.0285         0.549
# 3          74  11LmqTE2naFULdEP94AUBa        0.1990         0.256
# 4          73  119c93MHjrDLJTApCVGpvx        0.5700         0.479
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0       238640   0.430          0.000141    7    0.1290    -9.935     1
# ...

# %%
spotify1994= pd.read_csv("spotify1994.csv")
spotify1994.head()
# Out:
#    Unnamed: 0                                              track  \
# 0           0                    All I Want for Christmas Is You
# 1           1  Let It Snow! Let It Snow! Let It Snow! (with T...
# 2           2                  Christmas (Baby Please Come Home)
# 3           3                                       O Holy Night
# 4           4                                    Say It Ain't So
#
#           artist  popularity                      id  acousticness  \
# 0   Mariah Carey          93  0bYg9bo50gSsH3LtXe2SQn       0.16400
# 1  Frank Sinatra          87  4kKdvXD0ez7jp1296JmAts       0.90300
# 2   Mariah Carey          83  3PIDciSFdrQxSQSihim3hN       0.02200
# 3   Mariah Carey          77  3B7FO3kJ5kv3mX7yiaB7sT       0.36700
# 4         Weezer          73  6VoIBz0VhCyz7OdEoRYDiA       0.00737
#
#    danceability  duration_ms  energy  instrumentalness  key  liveness  \
# 0         0.335       241107   0.625          0.000000    7    0.0708
# ...

# %%
spotify1995= pd.read_csv("spotify1995.csv")
spotify1995.head()
# Out:
#    Unnamed: 0                    track         artist  popularity  \
# 0           0  Wonderwall - Remastered          Oasis          71
# 1           1       Gangsta's Paradise         Coolio          80
# 2           2          Check Yes Or No  George Strait          68
# 3           3        Always Be My Baby   Mariah Carey          73
# 4           4            I Got 5 On It          Luniz          73
#
#                        id  acousticness  danceability  duration_ms  energy  \
# 0  5wj4E6IsrVtn8IBJQOd0Cl      0.000453         0.372       258733   0.865
# 1  7lQWRAjyhTpCWFC0jmclT4      0.065500         0.647       240693   0.514
# 2  6iy4PoAuZBMvtrlDX4VxC7      0.055100         0.708       200667   0.524
# 3  2aBxt229cbLDOvtL7Xbb9x      0.457000         0.649       258133   0.531
# 4  4IYKjN1DrYzxKXt0umJqsG      0.209000         0.600       253533   0.706
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# ...

# %%
spotify2000= pd.read_csv("spotify2000.csv")
spotify2000.head()
# Out:
#    Unnamed: 0                track              artist  popularity  \
# 0           0           In the End         Linkin Park          83
# 1           1           Kryptonite        3 Doors Down          77
# 2           2  The Real Slim Shady              Eminem          80
# 3           3          Ms. Jackson             OutKast          77
# 4           4       This Christmas  Christina Aguilera          77
#
#                        id  acousticness  danceability  duration_ms  energy  \
# 0  60a0Rd6pjrkxjPbaKzXjfq       0.00958         0.556       216880   0.864
# 1  6ZOBP3NvffbU4SZcrnt1k6       0.00664         0.545       233933   0.865
# 2  3yfqSUWxFvZELEM4PmlwIR       0.03020         0.949       284200   0.661
# 3  0I3q5fE6wg7LIfHGngUTnV       0.14200         0.843       270507   0.805
# 4  32h59T8q2SonUPJ006lyXt       0.06870         0.575       241507   0.744
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# ...

# %%
spotify2005= pd.read_csv("spotify2005.csv")
spotify2005.head()
# Out:
#    Unnamed: 0                                     track               artist  \
# 0           0                         Hey There Delilah      Plain White T's
# 1           1                I Write Sins Not Tragedies  Panic! At The Disco
# 2           2                    Sugar, We're Goin Down         Fall Out Boy
# 3           3  Lose Yourself - From "8 Mile" Soundtrack               Eminem
# 4           4                            Feel Good Inc.             Gorillaz
#
#    popularity                      id  acousticness  danceability  \
# 0          80  4RCWB3V8V0dignt99LZ8vH       0.87200         0.657
# 1          74  4bPQs0PHn4xbipzdPfn6du       0.09380         0.567
# 2          77  2TfSHkHiFO4gRztVIkggkE       0.00579         0.494
# 3          77  5Z01UMMf7V1o0MzF86s6WJ       0.00868         0.692
# 4          80  0d28khcov6AiegSCpG5TuT       0.00836         0.818
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# ...

# %%
spotify2010= pd.read_csv("spotify2010.csv")
spotify2010.head()
# Out:
#    Unnamed: 0                                  track             artist  \
# 0           0  Happy Xmas (War Is Over) - Remastered        John Lennon
# 1           1                   Just the Way You Are         Bruno Mars
# 2           2                       Hey, Soul Sister              Train
# 3           3    No Hands (feat. Roscoe Dash & Wale)  Waka Flocka Flame
# 4           4                   Love The Way You Lie             Eminem
#
#    popularity                      id  acousticness  danceability  \
# 0          87  3zJw3rugfpVrmBeDDnUYzy       0.31900         0.328
# 1          80  7BqBn9nzAq8spo5e7cZ0dJ       0.01510         0.637
# 2          82  4HlFJV71xXKIGcU3kRyttv       0.18500         0.673
# 3          74  03tqyYWC9Um2ZqU0ZN849H       0.00544         0.760
# 4          82  15JINEqzVMv3SvJTAXAKED       0.24100         0.749
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# ...

# %%
spotify2015= pd.read_csv("spotify2015.csv")
spotify2015.head()
# Out:
#    Unnamed: 0                       track           artist  popularity  \
# 0           0  The Less I Know The Better      Tame Impala          85
# 1           1                       Don't    Bryson Tiller          80
# 2           2                    Exchange    Bryson Tiller          79
# 3           3                   The Hills       The Weeknd          84
# 4           4           Tennessee Whiskey  Chris Stapleton          77
#
#                        id  acousticness  danceability  duration_ms  energy  \
# 0  6K4t31amVTZDgR3sKmwUJJ        0.0115         0.640       216320   0.740
# 1  3pXF1nA74528Edde4of9CC        0.2220         0.765       198293   0.356
# 2  43PuMrRfbyyuz4QpZ3oAwN        0.1080         0.530       194613   0.433
# 3  7fBv7CLKzipRk6EC6TWHOB        0.0671         0.580       242253   0.565
# 4  3fqwjXwUGN6vbzIwvyFMhx        0.2050         0.392       293293   0.370
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# ...

# %%
spotify2019= pd.read_csv("spotify2019.csv")
spotify2019.head()
# Out:
#    Unnamed: 0                                     track          artist  \
# 0           0                                   The Box     Roddy Ricch
# 1           1                                   ROXANNE  Arizona Zervas
# 2           2                                   Circles     Post Malone
# 3           3  Bandit (with YoungBoy Never Broke Again)      Juice WRLD
# 4           4                                       BOP          DaBaby
#
#    popularity                      id  acousticness  danceability  \
# 0          95  0nbXyq5TXYPCO7pr3N8S4I        0.1040         0.896
# 1          99  696DnlkuDOXcMAnKlTgXXK        0.0522         0.621
# 2          98  21jGcNKet2qwijlDFuPiPb        0.1920         0.695
# 3          93  6Gg1gjgKi2AK4e0qzsR7sd        0.0687         0.474
# 4          93  6Ozh9Ok6h4Oi1wUSLtBseN        0.1890         0.769
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# ...

# %%
spotify_join=spotify1990.append(spotify1991)
spotify_join
# Out:
#      Unnamed: 0                                              track  \
# 0             0                                 Carol of the Bells
# 1             1                                     This Christmas
# 2             2                                      Thunderstruck
# 3             3                         Don't Go Breaking My Heart
# 4             4                                     Man in the Box
# 5             5                                             Poison
# 6             6                                     Can I Kick It?
# 7             7                                     Hard To Handle
# 8             8                                    More Than Words
# 9             9                                  Cowboys from Hell
# 10           10                                She Talks To Angels
# 11           11                                 U Can't Touch This
# 12           12                              What I Like About You
# ...

# %%
spotify_join_2=spotify_join.append(spotify1992)
spotify_join_2
# Out:
#      Unnamed: 0                                              track  \
# 0             0                                 Carol of the Bells
# 1             1                                     This Christmas
# 2             2                                      Thunderstruck
# 3             3                         Don't Go Breaking My Heart
# 4             4                                     Man in the Box
# 5             5                                             Poison
# 6             6                                     Can I Kick It?
# 7             7                                     Hard To Handle
# 8             8                                    More Than Words
# 9             9                                  Cowboys from Hell
# 10           10                                She Talks To Angels
# 11           11                                 U Can't Touch This
# 12           12                              What I Like About You
# ...

# %%
spotify_join_3=spotify_join_2.append(spotify1993)
spotify_join_3
# Out:
#      Unnamed: 0                                              track  \
# 0             0                                 Carol of the Bells
# 1             1                                     This Christmas
# 2             2                                      Thunderstruck
# 3             3                         Don't Go Breaking My Heart
# 4             4                                     Man in the Box
# 5             5                                             Poison
# 6             6                                     Can I Kick It?
# 7             7                                     Hard To Handle
# 8             8                                    More Than Words
# 9             9                                  Cowboys from Hell
# 10           10                                She Talks To Angels
# 11           11                                 U Can't Touch This
# 12           12                              What I Like About You
# ...

# %%
spotify_join_4=spotify_join_3.append(spotify1994)
spotify_join_4
# Out:
#      Unnamed: 0                                              track  \
# 0             0                                 Carol of the Bells
# 1             1                                     This Christmas
# 2             2                                      Thunderstruck
# 3             3                         Don't Go Breaking My Heart
# 4             4                                     Man in the Box
# 5             5                                             Poison
# 6             6                                     Can I Kick It?
# 7             7                                     Hard To Handle
# 8             8                                    More Than Words
# 9             9                                  Cowboys from Hell
# 10           10                                She Talks To Angels
# 11           11                                 U Can't Touch This
# 12           12                              What I Like About You
# ...

# %%
spotify_join_5=spotify_join_4.append(spotify1995)
spotify_join_5.head()
# Out:
#    Unnamed: 0                       track                        artist  \
# 0           0          Carol of the Bells  Mykola Dmytrovych Leontovych
# 1           1              This Christmas                Donny Hathaway
# 2           2               Thunderstruck                         AC/DC
# 3           3  Don't Go Breaking My Heart                    Elton John
# 4           4              Man in the Box               Alice In Chains
#
#    popularity                      id  acousticness  danceability  \
# 0          79  4tHqQMWSqmL6YjXwsqthDI      0.994000         0.418
# 1          78  38xhBO2AKrJnjdjVnhJES6      0.292000         0.634
# 2          81  57bgtoPSgt236HzfBOd8kj      0.000147         0.501
# 3          69  5pKJtX4wBeby9qIfFhyOJj      0.177000         0.742
# 4          71  6gZVQvQZOFpzIy3HblJ20F      0.002290         0.346
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# ...

# %%
spotify_join_6=spotify_join_5.append(spotify2000)
spotify_join_6.head()
# Out:
#    Unnamed: 0                       track                        artist  \
# 0           0          Carol of the Bells  Mykola Dmytrovych Leontovych
# 1           1              This Christmas                Donny Hathaway
# 2           2               Thunderstruck                         AC/DC
# 3           3  Don't Go Breaking My Heart                    Elton John
# 4           4              Man in the Box               Alice In Chains
#
#    popularity                      id  acousticness  danceability  \
# 0          79  4tHqQMWSqmL6YjXwsqthDI      0.994000         0.418
# 1          78  38xhBO2AKrJnjdjVnhJES6      0.292000         0.634
# 2          81  57bgtoPSgt236HzfBOd8kj      0.000147         0.501
# 3          69  5pKJtX4wBeby9qIfFhyOJj      0.177000         0.742
# 4          71  6gZVQvQZOFpzIy3HblJ20F      0.002290         0.346
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# ...

# %%
spotify_join_7=spotify_join_6.append(spotify2005)
spotify_join_7.head()
# Out:
#    Unnamed: 0                       track                        artist  \
# 0           0          Carol of the Bells  Mykola Dmytrovych Leontovych
# 1           1              This Christmas                Donny Hathaway
# 2           2               Thunderstruck                         AC/DC
# 3           3  Don't Go Breaking My Heart                    Elton John
# 4           4              Man in the Box               Alice In Chains
#
#    popularity                      id  acousticness  danceability  \
# 0          79  4tHqQMWSqmL6YjXwsqthDI      0.994000         0.418
# 1          78  38xhBO2AKrJnjdjVnhJES6      0.292000         0.634
# 2          81  57bgtoPSgt236HzfBOd8kj      0.000147         0.501
# 3          69  5pKJtX4wBeby9qIfFhyOJj      0.177000         0.742
# 4          71  6gZVQvQZOFpzIy3HblJ20F      0.002290         0.346
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# ...

# %%
spotify_join_8=spotify_join_7.append(spotify2010)
spotify_join_8.head()
# Out:
#    Unnamed: 0                       track                        artist  \
# 0           0          Carol of the Bells  Mykola Dmytrovych Leontovych
# 1           1              This Christmas                Donny Hathaway
# 2           2               Thunderstruck                         AC/DC
# 3           3  Don't Go Breaking My Heart                    Elton John
# 4           4              Man in the Box               Alice In Chains
#
#    popularity                      id  acousticness  danceability  \
# 0          79  4tHqQMWSqmL6YjXwsqthDI      0.994000         0.418
# 1          78  38xhBO2AKrJnjdjVnhJES6      0.292000         0.634
# 2          81  57bgtoPSgt236HzfBOd8kj      0.000147         0.501
# 3          69  5pKJtX4wBeby9qIfFhyOJj      0.177000         0.742
# 4          71  6gZVQvQZOFpzIy3HblJ20F      0.002290         0.346
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# ...

# %%
spotify_join_9=spotify_join_8.append(spotify2015)
spotify_join_9.head()
# Out:
#    Unnamed: 0                       track                        artist  \
# 0           0          Carol of the Bells  Mykola Dmytrovych Leontovych
# 1           1              This Christmas                Donny Hathaway
# 2           2               Thunderstruck                         AC/DC
# 3           3  Don't Go Breaking My Heart                    Elton John
# 4           4              Man in the Box               Alice In Chains
#
#    popularity                      id  acousticness  danceability  \
# 0          79  4tHqQMWSqmL6YjXwsqthDI      0.994000         0.418
# 1          78  38xhBO2AKrJnjdjVnhJES6      0.292000         0.634
# 2          81  57bgtoPSgt236HzfBOd8kj      0.000147         0.501
# 3          69  5pKJtX4wBeby9qIfFhyOJj      0.177000         0.742
# 4          71  6gZVQvQZOFpzIy3HblJ20F      0.002290         0.346
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# ...

# %%
spotify_join_10=spotify_join_9.append(spotify2019)
spotify_join_10.head()
# Out:
#    Unnamed: 0                       track                        artist  \
# 0           0          Carol of the Bells  Mykola Dmytrovych Leontovych
# 1           1              This Christmas                Donny Hathaway
# 2           2               Thunderstruck                         AC/DC
# 3           3  Don't Go Breaking My Heart                    Elton John
# 4           4              Man in the Box               Alice In Chains
#
#    popularity                      id  acousticness  danceability  \
# 0          79  4tHqQMWSqmL6YjXwsqthDI      0.994000         0.418
# 1          78  38xhBO2AKrJnjdjVnhJES6      0.292000         0.634
# 2          81  57bgtoPSgt236HzfBOd8kj      0.000147         0.501
# 3          69  5pKJtX4wBeby9qIfFhyOJj      0.177000         0.742
# 4          71  6gZVQvQZOFpzIy3HblJ20F      0.002290         0.346
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# ...

# %%
spotify_join_10.to_csv("spotify_join.csv")

# %%
spotify_join_10.describe()
# Out:
#          Unnamed: 0    popularity  acousticness  danceability   duration_ms  \
# count  11000.000000  11000.000000  11000.000000  11000.000000  1.100000e+04
# mean     499.500000     53.861909      0.276520      0.583776  2.388397e+05
# std      288.688113     12.071292      0.300403      0.177919  8.551719e+04
# min        0.000000     31.000000      0.000000      0.000000  3.112400e+04
# 25%      249.750000     44.000000      0.022900      0.466000  1.918970e+05
# 50%      499.500000     52.000000      0.148000      0.598000  2.292270e+05
# 75%      749.250000     61.000000      0.469000      0.715000  2.730032e+05
# max      999.000000    100.000000      0.996000      0.980000  4.120258e+06
#
#              energy  instrumentalness           key      liveness  \
# count  11000.000000      11000.000000  11000.000000  11000.000000
# mean       0.606589          0.079143      5.255818      0.188204
# std        0.233839          0.221035      3.544813      0.155211
# ...
