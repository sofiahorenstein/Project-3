# %% [markdown]
# ### Dependencies

# %%
# %matplotlib inline

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Datasets

# %%
data = pd.read_csv("spotifyTOP.csv") 
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1                       track  \
# 0           0             0               0          Carol of the Bells
# 1           1             1               1              This Christmas
# 2           2             2               2               Thunderstruck
# 3           3             3               3  Don't Go Breaking My Heart
# 4           4             4               4              Man in the Box
#
#                          artist  popularity                      id  \
# 0  Mykola Dmytrovych Leontovych          79  4tHqQMWSqmL6YjXwsqthDI
# 1                Donny Hathaway          78  38xhBO2AKrJnjdjVnhJES6
# 2                         AC/DC          81  57bgtoPSgt236HzfBOd8kj
# 3                    Elton John          69  5pKJtX4wBeby9qIfFhyOJj
# 4               Alice In Chains          71  6gZVQvQZOFpzIy3HblJ20F
#
#    acousticness  danceability  duration_ms  ...  instrumentalness  key  \
# ...

# %%
# Drop irrelevant columns
# 11,000 songs
data2 = data.drop(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'id', 'duration_ms', 'key', 'mode', 'time_signature'], axis=1)
data2.head()
# Out:
#                         track                        artist  popularity  \
# 0          Carol of the Bells  Mykola Dmytrovych Leontovych          79
# 1              This Christmas                Donny Hathaway          78
# 2               Thunderstruck                         AC/DC          81
# 3  Don't Go Breaking My Heart                    Elton John          69
# 4              Man in the Box               Alice In Chains          71
#
#    acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# 0      0.994000         0.418   0.106          0.029200    0.1790   -22.507
# 1      0.292000         0.634   0.645          0.000000    0.2460    -9.200
# 2      0.000147         0.501   0.889          0.011400    0.2170    -5.175
# 3      0.177000         0.742   0.863          0.000006    0.0699    -7.823
# 4      0.002290         0.346   0.765          0.000008    0.2130    -8.558
#
#    speechiness    tempo  valence  top_song
# ...

# %%
# Fetch songs that made the 'Top'
# 'top_song' column includes: 0 = 'no', 1 = 'yes'
data3 = data2.loc[data2['top_song'] == 1]

# Reset index
data4 = data3.reset_index(drop=True)

top = data4.drop(['top_song'], axis=1)

top.head()
# Out:
#                         track            artist  popularity  acousticness  \
# 0  Don't Go Breaking My Heart        Elton John          69       0.17700
# 1                      Poison    Bell Biv DeVoe          66       0.00195
# 2              Hard To Handle  The Black Crowes          68       0.00216
# 3             More Than Words           Extreme          67       0.46700
# 4         She Talks To Angels  The Black Crowes          63       0.06340
#
#    danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 0         0.742   0.863          0.000006    0.0699    -7.823       0.0380
# 1         0.840   0.560          0.004170    0.6330   -10.530       0.2100
# 2         0.593   0.786          0.000667    0.3110    -3.596       0.0446
# 3         0.626   0.134          0.000000    0.1130   -14.898       0.0298
# 4         0.583   0.526          0.000123    0.2180    -5.781       0.0291
#
#      tempo  valence
# 0  131.196    0.776
# 1  111.815    0.775
# ...

# %%
# Fetch songs that did not make the 'Top'
data5 = data2.loc[data2['top_song'] == 0]

# Reset index
data6 = data5.reset_index(drop=True)

not_top = data6.drop(['top_song'], axis=1)

not_top.head()
# Out:
#                 track                        artist  popularity  acousticness  \
# 0  Carol of the Bells  Mykola Dmytrovych Leontovych          79      0.994000
# 1      This Christmas                Donny Hathaway          78      0.292000
# 2       Thunderstruck                         AC/DC          81      0.000147
# 3      Man in the Box               Alice In Chains          71      0.002290
# 4      Can I Kick It?          A Tribe Called Quest          69      0.173000
#
#    danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 0         0.418   0.106          0.029200     0.179   -22.507       0.0448
# 1         0.634   0.645          0.000000     0.246    -9.200       0.0376
# 2         0.501   0.889          0.011400     0.217    -5.175       0.0364
# 3         0.346   0.765          0.000008     0.213    -8.558       0.0413
# 4         0.848   0.666          0.000699     0.129    -6.547       0.2740
#
#      tempo  valence
# 0   46.718    0.800
# ...

# %% [markdown]
# ### Analysis

# %%
top_analysis = top.describe()
top_analysis
# Out:
#         popularity  acousticness  danceability       energy  instrumentalness  \
# count  1685.000000   1685.000000   1685.000000  1685.000000       1685.000000
# mean     58.278932      0.192998      0.628472     0.638512          0.027655
# std      13.082392      0.238418      0.155910     0.194841          0.123481
# min      32.000000      0.000005      0.130000     0.024200          0.000000
# 25%      49.000000      0.020100      0.529000     0.504000          0.000000
# 50%      57.000000      0.088300      0.634000     0.657000          0.000002
# 75%      67.000000      0.276000      0.741000     0.791000          0.000330
# max     100.000000      0.991000      0.980000     0.996000          0.965000
#
#           liveness     loudness  speechiness        tempo      valence
# count  1685.000000  1685.000000  1685.000000  1685.000000  1685.000000
# mean      0.178706    -7.776188     0.088760   120.229080     0.528665
# ...

# %%
not_top_analysis = not_top.describe()
not_top_analysis
# Out:
#         popularity  acousticness  danceability       energy  instrumentalness  \
# count  9315.000000   9315.000000   9315.000000  9315.000000       9315.000000
# mean     53.062909      0.291628      0.575691     0.600814          0.088457
# std      11.703219      0.307896      0.180444     0.239774          0.233177
# min      31.000000      0.000000      0.000000     0.000020          0.000000
# 25%      44.000000      0.023650      0.455000     0.439000          0.000000
# 50%      51.000000      0.167000      0.588000     0.630000          0.000017
# 75%      60.000000      0.509000      0.709000     0.793000          0.004550
# max      99.000000      0.996000      0.978000     1.000000          0.999000
#
#           liveness     loudness  speechiness        tempo      valence
# count  9315.000000  9315.000000  9315.000000  9315.000000  9315.000000
# mean      0.189922    -9.092337     0.085766   120.002727     0.524492
# ...
